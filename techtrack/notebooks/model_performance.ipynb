# %%
# model_performance.ipynb

import cv2
import numpy as np
import os

# %%
from techtrack.inference.preprocessing import capture_video
from techtrack.inference.object_detection import Model
from techtrack.inference.nms import filter as nms_filter
# %matplotlib inline

# %%
#  compute Intersection over Union (IoU)
def compute_iou(boxA, boxB):
    """
    Computes IoU between two bounding boxes.
    boxA and boxB are in the format (x, y, w, h)
    """
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[0] + boxA[2], boxB[0] + boxB[2])
    yB = min(boxA[1] + boxA[3], boxB[1] + boxB[3])

    interWidth = max(0, xB - xA)
    interHeight = max(0, yB - yA)
    interArea = interWidth * interHeight

    boxAArea = boxA[2] * boxA[3]
    boxBArea = boxB[2] * boxB[3]

    iou = interArea / float(boxAArea + boxBArea - interArea) if (boxAArea + boxBArea - interArea) > 0 else 0

    return iou

def read_ground_truth_bboxes(txt_file_path, image_width, image_height):
    bboxes = []
    class_ids = []
    with open(txt_file_path, 'r') as f:
        for line in f:
            # Assuming the text file format is: class_id x_center y_center width height (normalized values)
            parts = line.strip().split()
            if len(parts) >= 5:
                class_id = int(parts[0])
                x_center, y_center, w, h = map(float, parts[1:5])

                #  normalized coordinates to absolute pixel values
                x_center *= image_width
                y_center *= image_height
                w *= image_width
                h *= image_height

                #  center coordinates to top-left coordinates
                x = int(x_center - w / 2)
                y = int(y_center - h / 2)
                w = int(w)
                h = int(h)

                bboxes.append((x, y, w, h))
                class_ids.append(class_id)
    return bboxes, class_ids

#  YOLO files for Model 1
config_path_1 = '.\yolo_model_1\yolov4-tiny-logistics_size_416_1.cfg'      
weights_path_1 = '.\yolo_model_1\yolov4-tiny-logistics_size_416_1.weights' 
class_names_path_1 = '.\yolo_model_1\logistics.names' 

#  YOLO files for Model 2
config_path_2 = '.\yolo_model_2\yolov4-tiny-logistics_size_416_2.cfg'      # Update with your model's cfg file
weights_path_2 = '.\yolo_model_2\yolov4-tiny-logistics_size_416_2.weights' # Update with your model's weights file
class_names_path_2 = '.\yolo_model_2\logistics.names' # Update with your model's class names file

# %%
# Initialize 
model1 = Model(config_path_1, weights_path_1, class_names_path_1)
model2 = Model(config_path_2, weights_path_2, class_names_path_2)

# %%
image_dir = 'logistics'  


image_files = [f for f in os.listdir(image_dir) if f.endswith(('.png', '.jpg', '.jpeg'))]

#  counters for performance metrics
true_positives_model1 = 0
false_positives_model1 = 0
false_negatives_model1 = 0

true_positives_model2 = 0
false_positives_model2 = 0
false_negatives_model2 = 0

iou_threshold = 0.5  # IoU threshold for detection as true positive

# Process 
for image_file in image_files:
    image_path = os.path.join(image_dir, image_file)
    txt_file_path = os.path.join(image_dir, os.path.splitext(image_file)[0] + '.txt')
    print(f"Processing image: {image_file}")
    
    # Read 
    image = cv2.imread(image_path)
    if image is None:
        print(f"Error reading image {image_file}")
        continue
    
    image_height, image_width = image.shape[:2]
    if os.path.exists(txt_file_path):
        gt_bboxes, gt_class_ids = read_ground_truth_bboxes(txt_file_path, image_width, image_height)
    else:
        print(f"No ground truth file found for {image_file}")
        continue

        # Process with Model 1
    model1.set_frame_shape(image.shape)
    predict_output_1 = model1.predict(image)
    score_threshold = 0.5
    bboxes_1, class_ids_1, scores_1 = model1.post_process(predict_output_1, score_threshold)
    nms_iou_threshold = 0.4
    filtered_bboxes_1, filtered_class_ids_1, filtered_scores_1 = nms_filter(
        bboxes_1, class_ids_1, scores_1, nms_iou_threshold
    )
    
    # Process with Model 2
    model2.set_frame_shape(image.shape)
    predict_output_2 = model2.predict(image)
    bboxes_2, class_ids_2, scores_2 = model2.post_process(predict_output_2, score_threshold)
    filtered_bboxes_2, filtered_class_ids_2, filtered_scores_2 = nms_filter(
        bboxes_2, class_ids_2, scores_2, nms_iou_threshold
    )
    
    # Evaluate Model 1
    matched_gt_indices = []
    for i, pred_box in enumerate(filtered_bboxes_1):
        pred_class_id = filtered_class_ids_1[i]
        best_iou = 0
        best_gt_index = -1
        for j, gt_box in enumerate(gt_bboxes):
            if j in matched_gt_indices:
                continue
            if pred_class_id != gt_class_ids[j]:
                continue
            iou = compute_iou(pred_box, gt_box)
            if iou > best_iou:
                best_iou = iou
                best_gt_index = j
        if best_iou >= iou_threshold:
            true_positives_model1 += 1
            matched_gt_indices.append(best_gt_index)
        else:
            false_positives_model1 += 1
    false_negatives_model1 += len(gt_bboxes) - len(matched_gt_indices)
    
    # Evaluate Model 2
    matched_gt_indices = []
    for i, pred_box in enumerate(filtered_bboxes_2):
        pred_class_id = filtered_class_ids_2[i]
        best_iou = 0
        best_gt_index = -1
        for j, gt_box in enumerate(gt_bboxes):
            if j in matched_gt_indices:
                continue
            if pred_class_id != gt_class_ids[j]:
                continue
            iou = compute_iou(pred_box, gt_box)
            if iou > best_iou:
                best_iou = iou
                best_gt_index = j
        if best_iou >= iou_threshold:
            true_positives_model2 += 1
            matched_gt_indices.append(best_gt_index)
        else:
            false_positives_model2 += 1
    false_negatives_model2 += len(gt_bboxes) - len(matched_gt_indices)
    
    print("\n")
# Out:
# Processing image: -01-15-1-1-1-2-26_jpg.rf.eb62a0a5f84fcbdbc0910af072cf0072.jpg
#
#
# Processing image: -01-15-1-4-1-1-14_jpg.rf.2e89a06faa1c217b95a0e0d7177e8397.jpg
#
#
# Processing image: -01-15-1-4-1-4-111_jpg.rf.ead3505e4a61d1c97ae2e235b7b228d5.jpg
#
#
# Processing image: -01-15-1-4-1-5-45_jpg.rf.0797388e664e12ff935b062e665f32ac.jpg
#
#
# Processing image: -01-15-2-2-2-1-212_jpg.rf.c3706c341a4cbb939c5b1341793bc0d8.jpg
#
#
# Processing image: -01-15-2-3-2-4-37_jpg.rf.0a2f9cb02817b70c5a56c6082535a7b6.jpg
#
#
# Processing image: -01-16-1-1-1-1-20_jpg.rf.27f842b8dd4032c96ad8afc13dc855f8.jpg
#
#
# Processing image: -01-16-1-2-1-3-14_jpg.rf.c2febebedae30ca6c5d67ea7adf8973b.jpg
#
#
# Processing image: -01-16-2-1-2-4-20_jpg.rf.7de07f4de98267e416ac90e110467400.jpg
#
#
# Processing image: -01-16-2-1-2-5-44_jpg.rf.3db2a524f3617f046a2a3b9c48a0c5ee.jpg
#
#
# Processing image: -01-16-2-2-2-1-112_jpg.rf.7287af14c2a3f25b2611052832121828.jpg
#
#
# Processing image: -01-16-2-5-2-4-32_jpg.rf.7b1caf338cd52204fb89c8087a84cc2f.jpg
#
#
# Processing image: -01-16-3-1-3-1-282_jpg.rf.de726806964013c6df859393db3f9e5e.jpg
#
#
# Processing image: -01-16-3-1-3-1-441_jpg.rf.42389b75feb4c068dafc503e45475b2d.jpg
#
#
# Processing image: -01A44A23-9E0B-4EB4-9376-A14A40014000-png_jpg.rf.543fcff0c7fc7031ff9fd08d038f3ee5.jpg
#
#
# Processing image: -02538A50-72EA-4E77-B24C-D04E772E74AE-png_jpg.rf.cf5b56857855a77a4d3fe2e6eebbb168.jpg
#
#
# Processing image: -0254895D-831E-4725-A1FE-37D7EC4E42C1-png_jpg.rf.986d9d0716593de150ee3de310060433.jpg
#
#
# Processing image: -03-3-1-1110_jpg.rf.26a06e656d5f09d09f021f8ccb7f6ce1.jpg
#
#
# Processing image: -040585B0-923B-49A3-B6F7-D149A58534ED-png_jpg.rf.fbf303445a1db090a0db0f4c312c95bf.jpg
#
#
# Processing image: -04961DB4-19B1-4496-8952-86D709DEC283-png_jpg.rf.d31e0a56efe163f60f2bd42993ae5136.jpg
#
#
# Processing image: -0573F94C-289D-4503-A571-94C6C8C5674C-png_jpg.rf.889afa98cfe93cf574680b84321090bb.jpg
#
#
# Processing image: -0B43DB53-2377-4D6D-B5B8-60CBBAB90F88-png_jpg.rf.c86dd7b63fec7f38702d138dfcbad987.jpg
#
#
# Processing image: -0DB55AC0-C1EA-47D6-80E8-DD6C861D5B97-png_jpg.rf.c311b4440619cc42438a89e8987bfcf3.jpg
#
#
# Processing image: -0F4FFD71-64D8-4E13-B4E9-DAEACE1DD233-png_jpg.rf.8da3cc0345dce41fb453823ba9f4a3d2.jpg
#
#
# Processing image: -0FB0E465-1451-4618-84CD-1A1A88293B08-png_jpg.rf.fa89a107d964f4a55391e9c26f167eac.jpg
#
#
# Processing image: -1-DRY-CONTAINER-_-_png_jpg.rf.af49c95763d7179243f25c6bb47f3050.jpg
#
#
# Processing image: -10-12-2021-175356_jpg.rf.18c6bc9d7c03bde7cd3e19fbad90f149.jpg
#
#
# Processing image: -10-12-2021-183016_jpg.rf.2f57fd93faf3f8b55341ec665f01dd01.jpg
#
#
# Processing image: -10-12-2021-184748_jpg.rf.bc906bac92e6b789a40af32cba1cfd85.jpg
#
#
# Processing image: -101F7188-06B4-4FC2-B9FF-123C60B06606-png_jpg.rf.ae8129fcf48c1df38a6db83da8c9470f.jpg
#
#
# Processing image: -114_jpg.rf.88d726593e0c96445da5aea732a52fe2.jpg
#
#
# Processing image: -117_jpg.rf.7ae57309e7f8c5f73cb10c75c97b472e.jpg
#
#
# Processing image: -12915842-53D6-4016-AEE9-1E3E140BF4A2-png_jpg.rf.f86e808e938a8b8109cf531357f6fb65.jpg
#
#
# Processing image: -13-12-2021-163550_jpg.rf.501b8e8bf4354947c23569de4866336e.jpg
#
#
# Processing image: -13-12-2021-171353_jpg.rf.d14bdcdc4fc24c114b1da858c8340f40.jpg
#
#
# Processing image: -145_jpg.rf.bb2fd2806a87396b9f6fe31c52e27863.jpg
#
#
# Processing image: -1506EA3F-975C-4AED-B676-31B133CD7B45-png_jpg.rf.8a023fa3f4c03d105c0589edc57e0056.jpg
#
#
# Processing image: -162406AB-670D-4437-8884-16F0D54C43F6-png_jpg.rf.ebf748c44560667ed3b9444686bda83f.jpg
#
#
# Processing image: -16_jpg.rf.a30444bc12e5bb965f0831edd670ecf6.jpg
#
#
# Processing image: -17914F96-DBD6-49D7-B722-763408B57213-png_jpg.rf.28586bf0ff0bfe2870dccea3e19305b3.jpg
#
#
# Processing image: -17914F96-DBD6-49D7-B722-763408B57213-png_jpg.rf.dcee21ce9e46295e15effbef62e7e31c.jpg
#
#
# Processing image: -17_jpg.rf.7ac8836609167c6078152358f3e1f40f.jpg
#
#
# Processing image: -183_jpg.rf.cacb72f18987a4ace7b4f12677c97aab.jpg
#
#
# Processing image: -1CB4058F-662E-4470-8889-D0E5F9EAC264-png_jpg.rf.97c6898edf771f3df913071437e3547f.jpg
#
#
# Processing image: -1D1B75DE-43F8-43BD-A88D-9E3027C4741A-png_jpg.rf.0e7ad0f630d72b4eaf1cd9ee2bd3ca2e.jpg
#
#
# Processing image: -1D1CDAD8-AB52-4C15-99E1-0F46C88FD2BB-png_jpg.rf.f8e8577d2f442032be1964bdeb3eee99.jpg
#
#
# Processing image: -1D5949D1-5187-454E-8ACC-924AD82CAC9C-png_jpg.rf.00a1361722ce29b7aec3ed34f7db72ef.jpg
#
#
# Processing image: -1E0BFB6E-30D8-4FA3-B325-FD010ACDB292-png_jpg.rf.f319b4969b95cdab2c8af643fe9f7b33.jpg
#
#
# Processing image: -1EE5CA55-C89F-4985-8D4E-A56DBD1A1E96-png_jpg.rf.078a2d049cf45f0ede212cb2c4a9dfa5.jpg
#
#
# Processing image: -2022-08-24-183054_png_jpg.rf.6e77426c2675ed363488a1e498beacf0.jpg
#
#
# Processing image: -2229E395-534F-4F69-9F9B-80628BD8D5AC-png_jpg.rf.56fbb4f0f9d96f886bb6c95172b12a78.jpg
#
#
# Processing image: -22C97EA9-A33B-4CCD-941C-5A2130410D29-png_jpg.rf.a2ad923ed700f1275df35d046fe83e0d.jpg
#
#
# Processing image: -237_jpg.rf.8dacbb6decd6a0447b8fb1b3d269e60d.jpg
#
#
# Processing image: -2482581B-D45C-4C05-97F4-3105704DFABC-png_jpg.rf.233277e04904e092fb2553262e01aec3.jpg
#
#
# Processing image: -25B75F91-9590-4B9D-A441-755612305E00-png_jpg.rf.54b6c3d1eff467959b387643f68ea71d.jpg
#
#
# Processing image: -261_jpg.rf.945283593e6e6b77569c942555e32513.jpg
#
#
# Processing image: -26E94431-436C-4D19-87EF-144E489255ED-png_jpg.rf.df967c14a6720f1a3867fd04c22349d8.jpg
#
#
# Processing image: -2846226C-6A55-4876-B717-7F8A5FA4E560-png_jpg.rf.54fea0289a0574a3c8b319dd26624ec8.jpg
#
#
# Processing image: -294_jpg.rf.2e8141e4ebd1c014dc2fd8eeea230d21.jpg
#
#
# Processing image: -298_jpg.rf.7f544aa4e7645b98de02e81efff4f2c5.jpg
#
#
# Processing image: -2A001B29-AA7E-4E76-B9AE-5927E1A3B542-png_jpg.rf.0d59e736c53ab34549de146034fb3182.jpg
#
#
# Processing image: -2CED9A70-376F-4C6E-9D0F-7670A652C145-png_jpg.rf.fc7ffda84ce33b423195afb15114f0d0.jpg
#
#
# Processing image: -2D167FEF-45B8-440F-8753-1A4E04C7F0AA-png_jpg.rf.de3761f19a10192e8b1b1e1e4436140c.jpg
#
#
# Processing image: -2D839168-D231-4DD7-8B9D-7C814EE1566B-png_jpg.rf.2a8fed8e6f0d05fa6aa04a8759d873bc.jpg
#
#
# Processing image: -3083EF7D-5D3D-4430-B831-691B5955E740-png_jpg.rf.e85b2da4c04acb1cf65f7c5b142f87b0.jpg
#
#
# Processing image: -3163ca687f_jpg.rf.7a1301fbad4a2740b7a051d1aad31303.jpg
#
#
# Processing image: -3163ca687f_jpg.rf.a9261fef778d984694a730d35c0a2ee2.jpg
#
#
# Processing image: -326_jpg.rf.d776ea71afc51fe32475cb4e74c68e3e.jpg
#
#
# Processing image: -32B57B8F-DFE6-46BE-861C-1A9848452803-png_jpg.rf.a1c617d6dcbaaaa97d8fa4ca43dc6887.jpg
#
#
# Processing image: -33-_png_jpg.rf.dabd8d4c2424b66e9cd5c3e03b2cd3ee.jpg
#
#
# Processing image: -332D2462-631E-4F9D-914E-9EA5A217A8FA-png_jpg.rf.4ecf6b859a9254f4971746cbfabf1a4f.jpg
#
#
# Processing image: -3381FBA8-90BE-45E2-8F3E-627CF903A2FE-png_jpg.rf.92d5507f2513d2b5d30259add50aa051.jpg
#
#
# Processing image: -345_jpg.rf.355f59b172fb5d4309de6224ecd95809.jpg
#
#
# Processing image: -35C8F869-003E-4989-ADF3-F79D890A8FE4-png_jpg.rf.8645d001ec32e3a0fc166d38f675dd57.jpg
#
#
# Processing image: -37621770-EA10-4509-962F-29AD0F6F09D8-png_jpg.rf.cfc4cda5809c221cb0903cfc0d92508e.jpg
#
#
# Processing image: -398D11E1-12E9-4FE1-83DA-198B0C1A0D9D-png_jpg.rf.a7dc9ee73a153419fb0978d21dabea85.jpg
#
#
# Processing image: -3D2AD3E1-4617-4151-8A04-92A20E13A925-png_jpg.rf.1a3d5789192fe39d682c1acbc620f4cb.jpg
#
#
# Processing image: -3D5128F1-30BE-4617-87D6-DBA1B7BF88DF-png_jpg.rf.87320ab53b853bf0a7b385309488f11d.jpg
#
#
# Processing image: -3EFC4A6B-3110-48FC-AC22-404D9A3443DA-png_jpg.rf.c85a453a55cc428fc272ec20a01b0052.jpg
#
#
# Processing image: -3FE8B0CD-A85C-45D8-8B05-3565D4F82882-png_jpg.rf.cd4f24d7ababf29f04cb69130b7bb266.jpg
#
#
# Processing image: -41-_png_jpg.rf.4e2af349ed9be3cc94eacb024f9d6ebd.jpg
#
#
# Processing image: -42-_png_jpg.rf.f74e873f78a28970a2c9b8debbde6c0e.jpg
#
#
# Processing image: -420B178A-1068-4C65-B00F-763738FCB982-png_jpg.rf.6c649da79d65096c148865b59c9b7d7e.jpg
#
#
# Processing image: -423FE4FB-F3E1-4E8E-8A40-5A99AEF6C353-png_jpg.rf.105a1c602e4076aa460bf68bda9f986a.jpg
#
#
# Processing image: -430_jpg.rf.b8e2130a9e9d27f3264911df8764bd41.jpg
#
#
# Processing image: -457_jpg.rf.b05f792433b686e44c6f2b97637c17e3.jpg
#
#
# Processing image: -465396AA-4CB9-4625-A390-70D9E748937A-png_jpg.rf.2e7339e1ea47d5ea916c2822c2baff70.jpg
#
#
# Processing image: -4669828B-853B-4599-BED7-E52C405426C1-png_jpg.rf.21c093a3efa3330832ebdf5f673a24a4.jpg
#
#
# Processing image: -466AB82D-A2BB-459B-90BE-46296B9D88E8-png_jpg.rf.882beeda6084cfa1331772b41c0f4a0d.jpg
#
#
# Processing image: -469593C2-4B3A-4A0B-B78A-24B4A79CCC35-png_jpg.rf.73a97b301e808e93355e69c0ef48920c.jpg
#
#
# Processing image: -47751EF0-5524-43F1-89F8-56973F1D603D-png_jpg.rf.b2aea36164b801e2c6f274f22621d951.jpg
#
#
# Processing image: -481_jpg.rf.5e8181b7a6dc256f61ac4330277c7a83.jpg
#
#
# Processing image: -4D888E2B-7F5D-4626-B4FF-E092A163D4B5-png_jpg.rf.8c59840bac7f20281ceb85380c8a10a5.jpg
#
#
# Processing image: -4D888E2B-7F5D-4626-B4FF-E092A163D4B5-png_jpg.rf.c97eb0f40364c54c6af520b21368c8ae.jpg
#
#
# Processing image: -4DFF09F8-2283-495F-9C84-6A25870884F8-png_jpg.rf.3f8aa0065289f273a23ab41f17295fca.jpg
#
#
# Processing image: -4E26A992-CA6F-43A4-B40F-D9881EC94176-png_jpg.rf.af40113dd6f90245f38fd455b7738c6c.jpg
#
#
# Processing image: -4EBB551E-565E-4918-9FB5-D21C804298B6-png_jpg.rf.95e7988564fad94ed883f3ca5afb59bf.jpg
#
#
# Processing image: -5180738D-B3C6-4938-AD50-F7E50CE8F729-png_jpg.rf.c9af08a8e1d03430734b50465097ff52.jpg
#
#
# Processing image: -53C40FB0-F866-4F4A-A410-D32C65C75BB4-png_jpg.rf.7c0b9a30cf6f1e6a72988b93c32f36c1.jpg
#
#
# Processing image: -61DB2824-3E4C-44EB-BDA8-91E18B840415-png_jpg.rf.f13ff70627c617ac17fb6088c00dcd31.jpg
#
#
# Processing image: -63409F4A-0A97-45DB-9828-199BFFB83DF3-png_jpg.rf.bcf60996c2981befef062c708ad9bcb5.jpg
#
#
# Processing image: -63991B4F-9F98-4B3C-9CF4-B7985DB357D1-png_jpg.rf.26834429770d1110cfc04103d983029e.jpg
#
#
# Processing image: -64FEA10C-1F32-4982-91EE-6FCD11A89A15-png_jpg.rf.97b766ac170c350f873f5470ee73c1ad.jpg
#
#
# Processing image: -67A4D449-E510-4E00-9670-57BE579333CA-png_jpg.rf.bdb1773df08dbba121269a2004a9977c.jpg
#
#
# Processing image: -6895811E-6E26-4DBD-A7ED-F7A529684BBA-png_jpg.rf.dda69f86f1ee9ab7fd09308861fc2c90.jpg
#
#
# Processing image: -697E0253-D382-41FD-BD9B-CB5DE358A1D0-png_jpg.rf.2e55aeaaaa6baa3d978d89932f67e536.jpg
#
#
# Processing image: -6BB0AE42-9EC0-424C-931B-A410493BCDA4-png_jpg.rf.352ea7f5ba7de288635ab8d489acb107.jpg
#
#
# Processing image: -6C8B745B-F55C-4939-A549-004F539643BE-png_jpg.rf.6e21724b6741514b32c1c7d7a4e02bdd.jpg
#
#
# Processing image: -6CEAABEE-4CD1-4355-808B-EC5CCA98188E-png_jpg.rf.54f1fa16ebdcc308464ae67c94778d98.jpg
#
#
# Processing image: -6CFFD6FB-2A39-4815-8F6F-DFAC5E9F5DB8-png_jpg.rf.06ffcc635055394ce0cd6441207af66f.jpg
#
#
# Processing image: -6D282D80-AF13-4D14-919D-C071DD61EDCE-png_jpg.rf.db31c0cb2c08b682817287ca596a57ba.jpg
#
#
# Processing image: -6E1F9232-59D2-4C19-94D6-826A8A2049C8-png_jpg.rf.3fa5be8dd61974340b6b2113bb07b87b.jpg
#
#
# Processing image: -6E572C75-A448-49CF-86E8-9F1364971CB1-png_jpg.rf.3d0cc45bd234105263cf5d784f2bf940.jpg
#
#
# Processing image: -6EDBF25D-DB21-48EE-85C6-D053CD8F2E69-png_jpg.rf.5bf080145843760fa8521ff12acfdd60.jpg
#
#
# Processing image: -707086FD-2D7E-442B-97AA-1527A86D587F-png_jpg.rf.968d29f1aab7b7981d7f6bfe7bcc823f.jpg
#
#
# Processing image: -71732B05-77D2-45D7-8CA5-DD48C574396A-png_jpg.rf.919632970aee03908581660be1a94d02.jpg
#
#
# Processing image: -75BF4E59-CCE7-459E-AEA7-936F84CB3E7B-png_jpg.rf.70629d37e113e8aa4660628609c789fb.jpg
#
#
# Processing image: -76693426-0372-4CEB-9177-296792EEFCB6-png_jpg.rf.db782d6b7d727f806ea8c4b061f9069b.jpg
#
#
# Processing image: -7B251052-06A6-45C6-8935-A2EAE66BB463-png_jpg.rf.260e49098e461a842e7365825868c89a.jpg
#
#
# Processing image: -7BB7C449-A5BF-41D8-B9CE-C083C6E6546E-png_jpg.rf.0f5b8fcc2f6dd305c701085cff1bd7a1.jpg
#
#
# Processing image: -7E2BE9C3-F989-4E5F-B605-E250E41C4FFA-png_jpg.rf.09391b7fd1ed19a7dd11af3261e8254f.jpg
#
#
# Processing image: -7E896192-D1B6-4B05-9FC3-AD6802AF0A5A-png_jpg.rf.b1b027d24ff52ff6dfafe07a14a52c5d.jpg
#
#
# Processing image: -7FAF411D-CD18-4902-9409-0DA28E30E6D5-png_jpg.rf.dd3a7d78a6a54843f3e540d8facb3b89.jpg
#
#
# Processing image: -81_jpg.rf.faa9a4c436182255c6e1bfc398331814.jpg
#
#
# Processing image: -869AA4A1-48C5-472A-AEA6-D46E499B10BC-png_jpg.rf.af007266a6f484c1f354b7c0836e9477.jpg
#
#
# Processing image: -870A135F-015A-4C8B-BC45-631925F80739-png_jpg.rf.ef85066ca54906752d031501604b7e63.jpg
#
#
# Processing image: -8A35D79B-CF9E-4E9D-A3F6-5D9479E17444-png_jpg.rf.915eeb41285f0282c09e8b62c1a3c6a6.jpg
#
#
# Processing image: -8B1E1BDB-65DC-4759-BC91-0D887006C34E-png_jpg.rf.bb450fa702ed03745ff4bae6b6b32c08.jpg
#
#
# Processing image: -8B24C687-2969-4359-A7CC-D702785148AE-png_jpg.rf.b79719076c6db132c75660a2345bb4c5.jpg
#
#
# Processing image: -8C4766F7-4A6D-4A1F-A334-D1ECFEC23D56-png_jpg.rf.ee8a363d5ed6f30281fd2f07db855555.jpg
#
#
# Processing image: -8D8C45A6-6F74-4EE8-8B27-92EF359C677A-png_jpg.rf.305ab0b9873fca6ea9eaa111cbc116b9.jpg
#
#
# Processing image: -912F672C-C08C-4C1D-B52A-B4F17E6C57FE-png_jpg.rf.9921e5d0bb27e740d9ff7a0f40093ef2.jpg
#
#
# Processing image: -98A01F02-3CDB-4F80-B347-F645B271B2FD-png_jpg.rf.0fb5fb3f2208a1266acbdc36ef0cd322.jpg
#
#
# Processing image: -9C23A8B1-74DC-44CD-B84A-852A9C7DDD1D-png_jpg.rf.6dc93d1a358bbd42dc6a920d776854ff.jpg
#
#
# Processing image: -9E5DCDFE-604C-4774-9BCC-613523B3EC83-png_jpg.rf.f432dcbd4cfb674f79d01b255c28dbed.jpg
#
#
# Processing image: -9F9F0E6A-CA31-49AA-BBA6-15712933D355-png_jpg.rf.b734118f73e17d68eb791a10d6e4fea4.jpg
#
#
# Processing image: -AC970550-9164-410F-959C-339BD2AEE096-png_jpg.rf.6d5031506927b850b060d1fcd99b55d2.jpg
#
#
# Processing image: -ADDC333A-6148-4B35-AE1D-3579229AEABB-png_jpg.rf.d5f50daeb2e3518045cba57be20990a5.jpg
#
#
# Processing image: -C6E3BB9A-DF12-4C1E-B325-8480F9DDDF74-png_jpg.rf.2f5583d3548437da2538d1aeb629b06d.jpg
#
#
# Processing image: -c7cae33d7d_jpg.rf.0384fda2dc5d7f0fad1d917c568e0aa1.jpg
#
#
# Processing image: -c7cae33d7d_jpg.rf.826b69fdaf7bcf8e6aab188d9eac4d82.jpg
#
#
# Processing image: -c7cae33d7d_jpg.rf.c67b14ae07b3947f23d8fbfc342eb741.jpg
#
#
# Processing image: -C94BD3BA-D8CC-4B20-A98D-914B04996466-png_jpg.rf.6edf525a6c5d2c90f5dca40ac8fe1033.jpg
#
#
# Processing image: -CB322478-2B8D-4479-A946-48DD7E5A4FA9-png_jpg.rf.41bfbe633929e39824e8b5db3ca09efc.jpg
#
#
# Processing image: -CED5E882-004A-471E-8E9A-EFE39FECCC62-png_jpg.rf.a36d3b33df899a865ea7dbac6bc52460.jpg
#
#
# Processing image: -CED5E882-004A-471E-8E9A-EFE39FECCC62-png_jpg.rf.e6fa143b81b7b75f00d35f71cb77e460.jpg
#
#
# Processing image: -D1325F22-9C5C-4457-B2F9-8A2F12A87948-png_jpg.rf.4ce83c7f4a1ee99dac5031f9bd4cf5b4.jpg
#
#
# Processing image: -D276856D-8655-4E00-9B81-7746DB0426B0-png_jpg.rf.e30a8e4c0d7a02b21766e82d5c521fb1.jpg
#
#
# Processing image: -D2E14C07-BFC7-406C-B5DC-277BF05F96B4-png_jpg.rf.61a50780d3f52f9ee07ce020a9de9330.jpg
#
#
# Processing image: -D3ED54BD-094A-471D-A8A9-C1A7B3262064-png_jpg.rf.3034904074e10fc9da850dab7c4ba030.jpg
#
#
# Processing image: -D57DACCE-A706-46AD-803E-1030E12D32C9-png_jpg.rf.96b584ccf974917372f4c2a50b38b3f3.jpg
#
#
# Processing image: -D6C38741-2164-4DC8-9271-C27E407A47BD-png_jpg.rf.b7418d54ad04ad35e4185082228216cc.jpg
#
#
# Processing image: -D7BF0066-D7EC-444A-8E5A-6886FDE98F3C-png_jpg.rf.5a5052e20cc56e56964cf507a7e44a6b.jpg
#
#
# Processing image: -DE08089E-9C98-4643-B056-358B21F13523-png_jpg.rf.6af9d99b840364fa6c8099a10c26d893.jpg
#
#
# Processing image: -DE0CF99E-6A90-4A84-8986-D616A113B706-png_jpg.rf.ee74d846dd2ea0644376820f1a1cc017.jpg
#
#
# Processing image: -DE1082FD-0948-4DF8-ABB3-902022027FE2-png_jpg.rf.312165abe3906289300d7878ed4857db.jpg
#
#
# Processing image: -e38a6febcc_jpg.rf.82dc88deb225552955ae45e16f4cf50f.jpg
#
#
# Processing image: -e38a6febcc_jpg.rf.8c8a609bbf81803ccf889210af5a4b39.jpg
#
#
# Processing image: -E3946BDE-6011-4240-B224-C2AF2FEE29FC-png_jpg.rf.bc8c1940ff8daa16ba25bf2f6a3bd72b.jpg
#
#
# Processing image: -E39DE576-0BDF-4674-9CCE-4780BD8A5744-png_jpg.rf.b790b707179c50a099686baef24f8f66.jpg
#
#
# Processing image: -E3D97881-36CB-441A-ADCA-6CB990F646FE-png_jpg.rf.b3534b2967d948e370676b682c4354a8.jpg
#
#
# Processing image: -E4771E07-DFCE-46C8-8081-70EB86A93970-png_jpg.rf.ed1735380d95115b71abe730242913a6.jpg
#
#
# Processing image: -E4E37ACE-EAB9-4F03-8279-813B05F79336-png_jpg.rf.0f51de3533ae4b4b1989035f4d77abaf.jpg
#
#
# Processing image: -E9B93242-136F-49A0-8906-3B6573D9BC59-png_jpg.rf.734d8588302ee2ca658e69e0ffc80fef.jpg
#
#
# Processing image: -F3A221BA-F8F5-4505-A9C2-35C1A9218266-png_jpg.rf.2c61af0525341b60a249cd8e4aff262e.jpg
#
#
# Processing image: -YouTube-Whale-2022-08-24-18-37-38_Moment-2-_jpg.rf.a84a613a368ab8577b71cdeaad176cf5.jpg
#
#
# Processing image: -_10_jpg.rf.7216b8fd23d002354ad6cdd0d7691cd5.jpg
#
#
# Processing image: -_57_jpg.rf.6e1bb5dc88e21ab791822b05fcec7d3d.jpg
#
#
# Processing image: 000000002261_jpg.rf.2334da0c48f20646cce37f4481cc2edd.jpg
#
#
# Processing image: 000000003553_jpg.rf.a2ffa655926b9f707e918291b41e7e6f.jpg
#
#
# Processing image: 000000006460_jpg.rf.05da95b30dd1b78f41e71a4a487f4ba3.jpg
#
#
# Processing image: 0000000071_jpg.rf.d9cd6b4edc4fc3a91d1679d6a3940e08.jpg
#
#
# Processing image: 0000000115_jpg.rf.a977ec8025af423712e226813f1687f2.jpg
#
#
# Processing image: 000000015335_jpg.rf.34abc05d02ab8cb26e8e232b0d6dd126.jpg
#
#
# Processing image: 0000000164_jpg.rf.92e71974166269bf1c86a81af2136e6b.jpg
#
#
# Processing image: 000000024243_jpg.rf.fa252142c4370e3deee0fb500256eaa4.jpg
#
#
# Processing image: 00000003_jpg.rf.2c1337911a2358d910824d173f20dd0e.jpg
#
#
# Processing image: 0000000429_jpg.rf.2d170ed5262050043fc9d8a97417326f.jpg
#
#
# Processing image: 0000000527_jpg.rf.ab481c97b6b6d0f1d190677813f69f1b.jpg
#
#
# Processing image: 000000066771_jpg.rf.8564fbe35c5505329824d7482b1b6398.jpg
#
#
# Processing image: 000000079969_jpg.rf.521fd3c9070018b9be80ad6b4ae3fb24.jpg
#
#
# Processing image: 0000000863_jpg.rf.ef0aa2c28e6cd62ab5d076088448aff8.jpg
#
#
# Processing image: 00000009_jpg.rf.f1818b50934bf02cb11e8514aef0e246.jpg
#
#
# Processing image: 00000010_jpg.rf.4f0fba34e85afd7cf35cfc31803dc6c9.jpg
#
#
# Processing image: 00000074_jpg.rf.cb8bd133ed32926405e53d0ea65f7e50.jpg
#
#
# Processing image: 00000111_jpg.rf.427970c00f47684c97523af211d8aace.jpg
#
#
# Processing image: 00000112_jpg.rf.0c27105c61ddc4ecb11e04331f8733f5.jpg
#
#
# Processing image: 00000131_jpg.rf.cf35a730a9f33a9a0409410bf9210523.jpg
#
#
# Processing image: 00000166_jpg.rf.3e48ba0c965cf4a99e1cdd9338184346.jpg
#
#
# Processing image: 00000192_jpg.rf.db32e18d4f0a3359cb6dbbf5897d1304.jpg
#
#
# Processing image: 00000216_jpg.rf.e93e2dca114dfd30e6763db0603dbe4b.jpg
#
#
# Processing image: 00000264_jpg.rf.1946eeb1fb54f1fcc83f1ad5d8edc4ce.jpg
#
#
# Processing image: 000002_jpg.rf.f1c86f181f1c7cb6b75b0d553cf57d54.jpg
#
#
# Processing image: 00000331_jpg.rf.116276d001da95b065645433ae562680.jpg
#
#
# Processing image: 0000039_jpg.rf.aeb1c9ad5d11bd4a7a6bd8e6c1c3a33b.jpg
#
#
# Processing image: 000003_jpg.rf.844d8aa4ad8e9953a76b895f0c4745f8.jpg
#
#
# Processing image: 00000432_jpg.rf.fb4856c8dce1509d27d13f165c044eb0.jpg
#
#
# Processing image: 00000454_jpg.rf.54b7e1e7271135e8cac4c46c639c8894.jpg
#
#
# Processing image: 00000480_jpg.rf.0f13f011a49bfd3ce4bbbb6beab0aa58.jpg
#
#
# Processing image: 0000048549557964_jpg.rf.35e065c49fcd170e57a1fabbb2142899.jpg
#
#
# Processing image: 000004_jpg.rf.62a2610a8a6656bec546826574f90581.jpg
#
#
# Processing image: 00000549_jpg.rf.cfe176a0598e3aec84cc3813477c5da6.jpg
#
#
# Processing image: 00000549_jpg.rf.f55659eadc6d59f394a6eb92dbbb003a.jpg
#
#
# Processing image: 00000584_jpg.rf.415487cc876b848ff105c5e1b6ce4e6e.jpg
#
#
# Processing image: 00000642_jpg.rf.afcdc4084e2aa02f92f29e6a0f8721cf.jpg
#
#
# Processing image: 000006_jpg.rf.42f0b17009eafa6d6557123f2d1cdc45.jpg
#
#
# Processing image: 000006_jpg.rf.c0282cfa5e63d2fcc4741e0abb94d7e2.jpg
#
#
# Processing image: 00000714_jpg.rf.805102ab1f884eac02fe853862681b5f.jpg
#
#
# Processing image: 0000072_jpg.rf.079e5e5c14ad40331cc2382ce68414ee.jpg
#
#
# Processing image: 00000853_jpg.rf.e8a0b3920cf207284f4be490615d8932.jpg
#
#
# Processing image: 0000095_jpg.rf.1170d0f26adbe9ef1ec822eb58b68985.jpg
#
#
# Processing image: 00000_00006_00023_png_jpg.rf.93b349d12094bfbef3b15095ffac21ae.jpg
#
#
# Processing image: 00001023_jpg.rf.2b3982c071c55f41f684e0bf28dd7428.jpg
#
#
# Processing image: 00001081_jpg.rf.cbc0bddef58a7fd10206ab400c564973.jpg
#
#
# Processing image: 00001130_jpg.rf.5b9fc8f590084277a7aa742a5bf1cb58.jpg
#
#
# Processing image: 00001152_jpg.rf.dc07deeb229823445fdf99d189dae2a9.jpg
#
#
# Processing image: 0000147617-e4eb190337827f8bbbcc9317d_jpg.rf.6a9734a0265bc7262e84ff76f18331b9.jpg
#
#
# Processing image: 0000161190-eff4a7d6440628a6ed58e9d9a_jpg.rf.c7b8b4a8bc71804e269b38abdba466b1.jpg
#
#
# Processing image: 00001777_jpg.rf.42f130f8d6f9962f0b8b6f3fc350804f.jpg
#
#
# Processing image: 00001839_jpg.rf.8f2506d82c272a2a406bd70179152a52.jpg
#
#
# Processing image: 00001990_jpg.rf.2758e074bb5353e50848e8a92fa51aa9.jpg
#
#
# Processing image: 00001_00043_00027_png_jpg.rf.795194bb4456b33dacba65378a8a1868.jpg
#
#
# Processing image: 00001_00070_00022_png_jpg.rf.e92e67d74fa4a4c9b1090ec8e0133192.jpg
#
#
# Processing image: 0000268_jpg.rf.43752d8ae7317360a71c45cad37dcee1.jpg
#
#
# Processing image: 0000380_jpg.rf.86876b8bd337b907c6e0da7ffbf0c27b.jpg
#
#
# Processing image: 0000397_jpg.rf.fadb88e75ea0da9823b4b3d1f933be8a.jpg
#
#
# Processing image: 0000410_jpg.rf.c5f4be191fefb274ebd7ddaf19bbed29.jpg
#
#
# Processing image: 0000648_jpg.rf.9422876f2efa32d790726e8def55a69d.jpg
#
#
# Processing image: 00006_jpg.rf.b4dfd64f680227fbd2424a48f5476115.jpg
#
#
# Processing image: 0000773_jpg.rf.0fc92c78c3a963e5d7007bd0089774b1.jpg
#
#
# Processing image: 0000773_jpg.rf.dddfbf763fb636161936199a6adc43dd.jpg
#
#
# Processing image: 0000942_jpg.rf.87573b54bf80e0bf6107476dec841ac1.jpg
#
#
# Processing image: 000095_jpg.rf.b46c4140759ed9c963b71e18128765d2.jpg
#
#
# Processing image: 000096_jpg.rf.c6f00395e3879601cffbaf6db6bfae6b.jpg
#
#
# Processing image: 000098_jpg.rf.2c74980d6e7f98962182e3075b132a6f.jpg
#
#
# Processing image: 0001047_jpg.rf.7bb96767de8ce4e879995425cd6cdf17.jpg
#
#
# Processing image: 0001048_jpg.rf.25d2ece9384d4ebd78c958b06c344a08.jpg
#
#
# Processing image: 00010_jpg.rf.e1455b61e910f2735fd7e87d61d67e3b.jpg
#
#
# Processing image: 0001278_jpg.rf.158cc5082579f49174cbfb95b6194e5a.jpg
#
#
# Processing image: 000127_jpg.rf.71948bbe759f577a3474808ddb25779c.jpg
#
#
# Processing image: 0001407_jpg.rf.ea93eb1b016d1f7bbd9f1c764b43a1c3.jpg
#
#
# Processing image: 0001489_jpg.rf.80b4019237d66bcd1512fcc56fd4e9b7.jpg
#
#
# Processing image: 0001552_jpg.rf.fcf148f281d5a8c64537fffca8c5f7d7.jpg
#
#
# Processing image: 0001657_jpg.rf.9e318d0de31a621a43a082a03f98bbe5.jpg
#
#
# Processing image: 00016_00013_00028_png_jpg.rf.4d5d8230b3fded4c128cfb69fd07a91f.jpg
#
#
# Processing image: 000186_jpg.rf.9ccfa1865a85c63787b32f9bf49b403e.jpg
#
#
# Processing image: 000189_jpg.rf.eb1263fffd522d2792f2c867aef6f37a.jpg
#
#
# Processing image: 00018_00002_00029_png_jpg.rf.5dd314f91d5cc9c83129395f50e09a2f.jpg
#
#
# Processing image: 00018_00003_00023_png_jpg.rf.90e0050c182a9f1d79557d9df2592736.jpg
#
#
# Processing image: 00018_00022_00002_png_jpg.rf.d5144c42f8fe5ea147a690638fd06ddf.jpg
#
#
# Processing image: 0001912_jpg.rf.e4e635417390fac1448aa6d9a30fbeaf.jpg
#
#
# Processing image: 0001914_jpg.rf.d0fbff733f15118d17d5e9f5a627eb73.jpg
#
#
# Processing image: 00019_00002_00027_png_jpg.rf.c6a317287cd1844c5d3d051748b994d5.jpg
#
#
# Processing image: 0002028_jpg.rf.31bd19f079eba04b6071341ce1c3b35e.jpg
#
#
# Processing image: 000206_jpg.rf.a8223e599f5c85552fa31dece5516cb1.jpg
#
#
# Processing image: 000212_jpg.rf.3cb1fa69c8594926cdcde97d18920fd3.jpg
#
#
# Processing image: 000215_jpg.rf.e4a23d7ee52e7054f37b16e7f19b92ba.jpg
#
#
# Processing image: 0002182_jpg.rf.f025a4d41068fa3a9596288c1149b2f1.jpg
#
#
# Processing image: 0002184_jpg.rf.3728718cee1a07b6077976f734ab0770.jpg
#
#
# Processing image: 000221_jpg.rf.4a83643c83fb72a653fc745833b7cede.jpg
#
#
# Processing image: 00023_00004_00028_png_jpg.rf.14cc855f3a3d7d2530b3997666ff71a5.jpg
#
#
# Processing image: 00023_00006_00023_png_jpg.rf.824a917cc96e32a1680ef6f4c448c092.jpg
#
#
# Processing image: 0002463_jpg.rf.c3a6d66d467a2824e5d861297b7d4a2d.jpg
#
#
# Processing image: 000247_jpg.rf.4fd3cc5c8e02765a0e4266363cba8786.jpg
#
#
# Processing image: 00024_00000_00023_png_jpg.rf.bae1d32caf1421c25337917c635d8418.jpg
#
#
# Processing image: 00024_00006_00028_png_jpg.rf.33bb494262b6f3ba913a98779cfaf2e9.jpg
#
#
# Processing image: 000254_jpg.rf.f684f4fa47617f8cf21357aa288e6093.jpg
#
#
# Processing image: 000255_jpg.rf.350faff8db02afa54ced9fab16ee85cc.jpg
#
#
# Processing image: 0002687_jpg.rf.77293ac693383d2be69d22ecc1721c00.jpg
#
#
# Processing image: 0002690_jpg.rf.6ee97d1caed4e4e501e3f6a79b17391e.jpg
#
#
# Processing image: 0002691_jpg.rf.ec4c7277f961a9fdbb817811cb8dcbc9.jpg
#
#
# Processing image: 0002721_jpg.rf.77f93dcc7b2a9eb6fe5c5e148d7d8eff.jpg
#
#
# Processing image: 0002721_jpg.rf.fe988453870217329b3b191e54861824.jpg
#
#
# Processing image: 0002745_jpg.rf.250a7b6f7eca24d0c5109b4f97613643.jpg
#
#
# Processing image: 0002774_jpg.rf.c2f5897ba00edfb82924d3d770ae06aa.jpg
#
#
# Processing image: 000277_jpg.rf.f2d5c57407b736c77da69cd8103d8ea8.jpg
#
#
# Processing image: 00027_00000_00029_png_jpg.rf.bf2fe7c0ee659c025fbb044e23239fe9.jpg
#
#
# Processing image: 0002804_jpg.rf.53bb8f56ae2590eb36691ffddb3576a6.jpg
#
#
# Processing image: 000282_jpg.rf.cd0c3fd82a4c429192008e208bac1308.jpg
#
#
# Processing image: 0002839_jpg.rf.339fc26f27ec016fee6785d8cc44035d.jpg
#
#
# Processing image: 000283_jpg.rf.138017ea4bf58503ecabfc26a0dcfdb6.jpg
#
#
# Processing image: 000286_jpg.rf.026afd3e2e53294cf3468001f882a154.jpg
#
#
# Processing image: 0002897_jpg.rf.6df9a87713c1a497453a3cda19303289.jpg
#
#
# Processing image: 0002898_jpg.rf.0f638461309abcfa356ce7543b4765be.jpg
#
#
# Processing image: 000303_jpg.rf.66460baf493715e6bda5a64104eaa14c.jpg
#
#
# Processing image: 000319_jpg.rf.ffd4fd1f461b3dbe7367f34a06742dbf.jpg
#
#
# Processing image: 0003228_jpg.rf.6bae45e60259ee94fbd04a09056a1999.jpg
#
#
# Processing image: 0003230_jpg.rf.433ec59a8d41d795df072b8a02746478.jpg
#
#
# Processing image: 0003307_jpg.rf.996c8ee33c1c5910edee278c34eed71b.jpg
#
#
# Processing image: 0003309_jpg.rf.72dae54fb6f150bdcad167acde0cc8a3.jpg
#
#
# Processing image: 0003346_jpg.rf.bb08591ed25ae31a41a7c087d49ed2ed.jpg
#
#
# Processing image: 00033_00013_00028_png_jpg.rf.533e7ece8cc0037a31d0c5d96442626e.jpg
#
#
# Processing image: 0003411_jpg.rf.dd427f5ef3124cb3109cc3a21a0652be.jpg
#
#
# Processing image: 000344d9009b4ef5_jpg.rf.8ff7ccd9a70e363d630e83babf9a27b1.jpg
#
#
# Processing image: 0003539_jpg.rf.22901230ba0f1762ba6fa95d76dd7493.jpg
#
#
# Processing image: 0003762_jpg.rf.7dcc2495f7873f20d775fecd3b47a18d.jpg
#
#
# Processing image: 0003858_jpg.rf.07357013a7cf0521df08f2ac1df07168.jpg
#
#
# Processing image: 000385_jpg.rf.177813b520133a6e8fa69ecda0607ef0.jpg
#
#
# Processing image: 000389_jpg.rf.313a91605b696210667a02f49874df46.jpg
#
#
# Processing image: 000389_jpg.rf.7a78d299473c44f755259864647cb717.jpg
#
#
# Processing image: 0004037_jpg.rf.39080a8ccb4d946dd7f39dc3db146754.jpg
#
#
# Processing image: 0004041_jpg.rf.2c4ca8651f174b042d30273c737cff12.jpg
#
#
# Processing image: 000404_jpg.rf.f1f2d613f3c462e3538f186dcbb10b97.jpg
#
#
# Processing image: 0004088_jpg.rf.66f0f3225cca0b9373e74a7cb1f35bc3.jpg
#
#
# Processing image: 00040_00005_00026_png_jpg.rf.0c6f696ad1c582fcab519aa068dd7722.jpg
#
#
# Processing image: 000416_jpg.rf.24a133876dcef2c1c8e7e300962fa417.jpg
#
#
# Processing image: 000423_jpg.rf.313242ef81c63346c80e0994fb646aad.jpg
#
#
# Processing image: 0004314_jpg.rf.2bff9a1a01c4b2bc3349073989503d84.jpg
#
#
# Processing image: 000465_jpg.rf.62ff7ca3023759fba6bbcff5c3c85f0f.jpg
#
#
# Processing image: 000467588f9797fc_jpg.rf.19aa28e0647d7055d875dbfb060cce8a.jpg
#
#
# Processing image: 000507_jpg.rf.228e8d1825d9e8a8e70104a054ad4927.jpg
#
#
# Processing image: 000516_jpg.rf.ccc34c68359a525e5be0ee86e597058b.jpg
#
#
# Processing image: 000526_jpg.rf.73de1b8973b3ac4768506f471b39b1a1.jpg
#
#
# Processing image: 000529_jpg.rf.2b922de71818664d3851d7847d2273b8.jpg
#
#
# Processing image: 000540_jpg.rf.cc84da91ffefdc4e2c701789a36f702a.jpg
#
#
# Processing image: 000548d21e085b90_jpg.rf.f706175f9ab6825481cccf36aae7a656.jpg
#
#
# Processing image: 000557_jpg.rf.44028c2b9b8008b7f6451678bcf9fb8d.jpg
#
#
# Processing image: 000558_jpg.rf.97ff06171e304c4ded93143580bb7838.jpg
#
#
# Processing image: 000562_jpg.rf.735f22be5dfaab23c1b7894e600a4c2d.jpg
#
#
# Processing image: 000576_jpg.rf.217ca252f7b20f28ff6e4191f14f5eb5.jpg
#
#
# Processing image: 000578_jpg.rf.56e1aef903525b480b5e2c7abf4cf274.jpg
#
#
# Processing image: 000592_jpg.rf.d25c62057ea0b561bf047fa4132d6e3c.jpg
#
#
# Processing image: 000617_jpg.rf.4a90f2d229f0a7a68031adc879d2d065.jpg
#
#
# Processing image: 000631_jpg.rf.4a67edbc54ce0d0e1f08360407f3f0eb.jpg
#
#
# Processing image: 000633_jpg.rf.1e35fa6f80857e433757023cb6fa1caa.jpg
#
#
# Processing image: 000647_jpg.rf.3bf92045d19515f5b77876ba30169a48.jpg
#
#
# Processing image: 00065e3d353618a3_jpg.rf.1b1320bea1b2d8cafb94e3dcedcb2c11.jpg
#
#
# Processing image: 000674_jpg.rf.5678c469c60f30b38859dc852ad1c524.jpg
#
#
# Processing image: 000675_jpg.rf.fd1020c5c02ee9c3f4a7974d2be41bcb.jpg
#
#
# Processing image: 000677_jpg.rf.8d7dd3d8eca5df2dc62f818bb78bf972.jpg
#
#
# Processing image: 00067_jpg.rf.f6ae7bec78891552d0841dd17c1319b0.jpg
#
#
# Processing image: 000682_jpg.rf.557e1e2d729ed0e0975bdf86f48b7f79.jpg
#
#
# Processing image: 000688_jpg.rf.27bc4e636df74ee1e734daad25b872d6.jpg
#
#
# Processing image: 000692d348b0f181_jpg.rf.cbb8073c63eeecf1d79bd4599976138c.jpg
#
#
# Processing image: 000726_jpg.rf.a2e66cc5c3204b92cf902edf29735490.jpg
#
#
# Processing image: 000747_jpg.rf.b4b36c5e176db5daf4c23b73322e3890.jpg
#
#
# Processing image: 000747_jpg.rf.df1953c7632092df8c9f0facbba8f494.jpg
#
#
# Processing image: 000810_jpg.rf.85c41f63ca7a3b6cae1f07cf217bae6a.jpg
#
#
# Processing image: 000822_jpg.rf.f6d5dbfc4766687ab1ad6753293ef2a8.jpg
#
#
# Processing image: 00082426f9139dd0_jpg.rf.844bc7f771d851a5667943ce3bfcf43e.jpg
#
#
# Processing image: 00084f5fbd30c301_jpg.rf.508999034ed5cea20317b7cf8ef12bb9.jpg
#
#
# Processing image: 0008563cc0b6e8b6_jpg.rf.347d19b4c65daccb26635a035ce3ae5c.jpg
#
#
# Processing image: 000858_jpg.rf.2ea9cc8ea2b32cbbf3d0080ec0320123.jpg
#
#
# Processing image: 000883_jpg.rf.5c0f4f7af918ff5dc0907a1a23840270.jpg
#
#
# Processing image: 000945_jpg.rf.80d5c1bb2ee507a78074ab017a8aa311.jpg
#
#
# Processing image: 00095_jpg.rf.9a078175e7312a815117a48e06898e0f.jpg
#
#
# Processing image: 001-3-_jpg.rf.255a93bf0d1868cccc68b0d43e0ecf4e.jpg
#
#
# Processing image: 001-5-_jpg.rf.47a591fc7e663f267779e455a11c3c43.jpg
#
#
# Processing image: 001040_jpg.rf.3851c1c588f6bf23b048673163bf155c.jpg
#
#
# Processing image: 001047_jpg.rf.6b09b6871e9ffaf1d1a4da3386ef79b6.jpg
#
#
# Processing image: 001061_jpg.rf.d37d74d94189d1871b3224723480d2ea.jpg
#
#
# Processing image: 001113_jpg.rf.ecaf411c2d14a81d100141477629a6cd.jpg
#
#
# Processing image: 001117_jpg.rf.c118fdf22d0c7cea7fb62d0a2460b10c.jpg
#
#
# Processing image: 00112_jpg.rf.9432bab908a25e5e8d03085e8fd43e7f.jpg
#
#
# Processing image: 001165bc0eec2a26_jpg.rf.690f1349794062c5730502f09370c65e.jpg
#
#
# Processing image: 00118eeac8c3325b_jpg.rf.57c683208e27d3679ecf5292d521ac96.jpg
#
#
# Processing image: 001195_jpg.rf.fb779a24810d7a74cc8487dec479a946.jpg
#
#
# Processing image: 00119_jpg.rf.19a874fa9ae65aea8be708caa177704f.jpg
#
#
# Processing image: 001202_jpg.rf.359dcb96d33272b4c63132a2a737b068.jpg
#
#
# Processing image: 001210_jpg.rf.d3a22ccac7c1f7bbab527a41cef784e6.jpg
#
#
# Processing image: 001210_jpg.rf.f3ef66671d5112e2cd7ce4b2889c08f6.jpg
#
#
# Processing image: 00121eb7671f8465_jpg.rf.2f978aaecd506011b9440e6eeb6fd7cf.jpg
#
#
# Processing image: 001222_jpg.rf.86bc04c483fb316f5328b4482d83cfa2.jpg
#
#
# Processing image: 001225_jpg.rf.f3ab1d3f100c23a674d9c8559aef6e8d.jpg
#
#
# Processing image: 001226_jpg.rf.772ad57ea06eaba380cb509ed856fd2b.jpg
#
#
# Processing image: 001287_jpg.rf.1ca2a0410dc9e8d1585cb402f4bd8ba2.jpg
#
#
# Processing image: 001300_jpg.rf.3cb9aa8511d9fcc6745ca4ea89501686.jpg
#
#
# Processing image: 001347_jpg.rf.63cbf3532f5813908624723631980ab7.jpg
#
#
# Processing image: 001353_jpg.rf.4fcc66798a2918c112236ea9bc9e754d.jpg
#
#
# Processing image: 001391_jpg.rf.14589c7e440facfdf1024dbd0c5da7d9.jpg
#
#
# Processing image: 001399_jpg.rf.e7a1a3bfaa417ba1501a9d51c239527d.jpg
#
#
# Processing image: 0014-3-_jpg.rf.abcd4a9cf3dd22ebf13bebf198a36b63.jpg
#
#
# Processing image: 001430_jpg.rf.f4c62e663bec1366d5d714e7c954ce94.jpg
#
#
# Processing image: 001443960156ea95_jpg.rf.d823f7aa9b7295c8583617938c99007b.jpg
#
#
# Processing image: 00144_jpg.rf.fbb03e3521b02e3c1f58470ad8ef0295.jpg
#
#
# Processing image: 001461e5869be249_jpg.rf.fd679b151410df105d48c9c044dc0829.jpg
#
#
# Processing image: 001463_jpg.rf.5b85900a42bcc378d55e00efc388d6f9.jpg
#
#
# Processing image: 001489_jpg.rf.5800a4e4d27b131863132f7c7deb8d69.jpg
#
#
# Processing image: 001509_jpg.rf.a774511f075166a9de0bd76e9154a1c9.jpg
#
#
# Processing image: 001557_jpg.rf.58d65935795cd3237f369ea5cbe40cb7.jpg
#
#
# Processing image: 0015725e676a5066_jpg.rf.4d39cb687b421e721748ac9b70ae775a.jpg
#
#
# Processing image: 00160895ce715368_jpg.rf.01af2fc585d08584a14a26976c50e5dd.jpg
#
#
# Processing image: 001647_jpg.rf.d9bb5790912f07a62de20902ad718728.jpg
#
#
# Processing image: 001689_jpg.rf.458d2349d9b669c198e3eb529337242c.jpg
#
#
# Processing image: 00171_jpg.rf.91f3c9d756648c08f3c9f7ec87a8dabc.jpg
#
#
# Processing image: 001755_jpg.rf.da1551dd88b1480580fe6297bea46b91.jpg
#
#
# Processing image: 00175_Ford-E-Series-Wagon-Van-2012_jpg.rf.bd73a24ab2c40aeb228d8bf19e106c25.jpg
#
#
# Processing image: 0018-4-_jpg.rf.c5eeb8b816041e951bce81ddffcabb5e.jpg
#
#
# Processing image: 001854_jpg.rf.02854c9f7ae1e193fcc1d7ad7d98629c.jpg
#
#
# Processing image: 001858_jpg.rf.2f1f0af0dbb2ef1e13cdb177aeb7b105.jpg
#
#
# Processing image: 001890_jpg.rf.b37bf2c7adb419419cfac86161ad366b.jpg
#
#
# Processing image: 001896_jpg.rf.baead63a9b5ac65d931f3a38d7ac64ad.jpg
#
#
# Processing image: 001900_jpg.rf.efac6565721505ce658941b5f9c0f70f.jpg
#
#
# Processing image: 001908_jpg.rf.c0a01738c5102defd56b6e19ae6f5d35.jpg
#
#
# Processing image: 001914_jpg.rf.2746eee4fed8bbce5508985793841557.jpg
#
#
# Processing image: 001945ad2301fe7a_jpg.rf.7ae713ca57ccd08facf66b535347410c.jpg
#
#
# Processing image: 001965_jpg.rf.7ed24f0abe1096c0d81e6067b04247cf.jpg
#
#
# Processing image: 002015e4c344d706_jpg.rf.a22369059629d160efcefd69e5f514bc.jpg
#
#
# Processing image: 002055_jpg.rf.22ebe23d07ea04deff83d95726aca531.jpg
#
#
# Processing image: 002087_jpg.rf.0368593682c0f5f1255875e35ab90666.jpg
#
#
# Processing image: 002202_jpg.rf.0e042d27421e553c35111c179e21d473.jpg
#
#
# Processing image: 002259_jpg.rf.52e8d7cfc34dcd33744055c46cae9a29.jpg
#
#
# Processing image: 002325_jpg.rf.bc16abd12c43a476482e6ba6db9f0a80.jpg
#
#
# Processing image: 002330c6a1c8c6cb_jpg.rf.7c6615c29f59a11c596fc29096be22c2.jpg
#
#
# Processing image: 002344_jpg.rf.63cea81b87df195a2b6a0bdae231a792.jpg
#
#
# Processing image: 0024-2-_jpg.rf.037776b138af3d5bf76e755816325a72.jpg
#
#
# Processing image: 002401_jpg.rf.8b24fc2ab6406e7787e100012567ee51.jpg
#
#
# Processing image: 002443_jpg.rf.8b7de22576457ff1f2fdf2f7e55640a4.jpg
#
#
# Processing image: 002487_jpg.rf.5ee3d04018042baec2ed3c0fbb882d48.jpg
#
#
# Processing image: 0024_jpg.rf.4a74d33a76341ab79ccca1625c43e30d.jpg
#
#
# Processing image: 00253_jpg.rf.aa17412237ad0660ba33a0d68510f2cd.jpg
#
#
# Processing image: 002582_jpg.rf.a1554519a84b97c275bfee7246493a47.jpg
#
#
# Processing image: 002584_jpg.rf.5c3e908326a456165e2317b559fc5433.jpg
#
#
# Processing image: 002622_jpg.rf.663f6157f4cf7cb15b0c017b1fcf6dda.jpg
#
#
# Processing image: 002641_jpg.rf.2eb76e3f63b66a059fc6297207eae766.jpg
#
#
# Processing image: 002666_jpg.rf.43c167fdbc87730ed0f4d71dfd009084.jpg
#
#
# Processing image: 002714_jpg.rf.76a29c3ac703833d32ff0b05b0d265fb.jpg
#
#
# Processing image: 002745_jpg.rf.499cfcf38b7db905ba2d829b519bd72a.jpg
#
#
# Processing image: 002762_jpg.rf.ef989576853fde74b462860bdc8cc7a6.jpg
#
#
# Processing image: 002782_jpg.rf.6c982a9dbced69c4f77bb7f2cd0bf5fd.jpg
#
#
# Processing image: 00280_jpg.rf.d82fee74454fa59c33894cdda998e445.jpg
#
#
# Processing image: 00284_jpg.rf.a89c672cd12d5ed445f943d35ae49aff.jpg
#
#
# Processing image: 00285_jpg.rf.585599b1d3ec154e924b607374428427.jpg
#
#
# Processing image: 002864_jpg.rf.11b3285bf2967b83292501a28756f398.jpg
#
#
# Processing image: 00296_jpg.rf.822fc69c83c94a75fa5b19ce46c66b1c.jpg
#
#
# Processing image: 002980_jpg.rf.c2145576da9f08e33fafe2ce5c0ea084.jpg
#
#
# Processing image: 003009_jpg.rf.2c677e077c60c6346e753e8f04bc95d7.jpg
#
#
# Processing image: 003012_jpg.rf.aec2536392447d4903f2c5c5814c6da6.jpg
#
#
# Processing image: 003033_jpg.rf.69e944becbd3e88b5bd08c8b413cc0c5.jpg
#
#
# Processing image: 003034_jpg.rf.c8dcd98b00aa87475b0e1ab6e57e1979.jpg
#
#
# Processing image: 003037_jpg.rf.f8ddec56daeb56ce1ad367f4b5f47bd2.jpg
#
#
# Processing image: 003107_jpg.rf.417ed2bfe23bff410c8d87e983d1885b.jpg
#
#
# Processing image: 003107_jpg.rf.92a8caf3324afd4496e2edfae8e01d1e.jpg
#
#
# Processing image: 003108_jpg.rf.c63ace028874dcae3112ab30ca5d51c6.jpg
#
#
# Processing image: 003115_jpg.rf.beb9dc82e7ddde37ba7f3bdaef94b67d.jpg
#
#
# Processing image: 003179_jpg.rf.f038023cf56d45254bef1bee65a3494b.jpg
#
#
# Processing image: 00320a4009f3dcd1_jpg.rf.551aee3fa2d05a6433863b94b883ac9c.jpg
#
#
# Processing image: 0032dd040a3481bb_jpg.rf.12e060daa3e1285ab110823b0ae863af.jpg
#
#
# Processing image: 00330_jpg.rf.533364ac2ce1412c5f78feb1c2271b15.jpg
#
#
# Processing image: 003339_jpg.rf.802717bd326579a75c29fbc85c98cdc0.jpg
#
#
# Processing image: 003384_jpg.rf.a2ea13d5f01e67623c8ec2a128181b35.jpg
#
#
# Processing image: 003396_jpg.rf.a5a58c9999a50bfc145802175c2e2061.jpg
#
#
# Processing image: 003400_jpg.rf.e7084aa603d7100f8f1fd6f879c1dfc0.jpg
#
#
# Processing image: 003412_jpg.rf.9acfa7caf22d678e3077aded7a7a99ce.jpg
#
#
# Processing image: 003413_jpg.rf.f462712604faa1d198663bfc28912c35.jpg
#
#
# Processing image: 003429_jpg.rf.bb1bc8d314967dbe38c6747994014f79.jpg
#
#
# Processing image: 00342_jpg.rf.045d2e383a06644ee5606ba61a045ed4.jpg
#
#
# Processing image: 003469_jpg.rf.1673ccb07c5caa3ba95136bd220f88d9.jpg
#
#
# Processing image: 003470_jpg.rf.2fd0cebfd7604fd70cc2f34b17624843.jpg
#
#
# Processing image: 003492_jpg.rf.7e94fa5302ecadbe17130239cfdd9e2e.jpg
#
#
# Processing image: 00353_jpg.rf.31bd8a5534445fe11ab105eaa2b69f9e.jpg
#
#
# Processing image: 003572_jpg.rf.31b1282a56fbcf9f7d08f304d050f73e.jpg
#
#
# Processing image: 003609_jpg.rf.ce36525cea5ff816e2f1e3f6fee426ff.jpg
#
#
# Processing image: 003620_jpg.rf.30783993960be6861eb53d6c9999fd48.jpg
#
#
# Processing image: 003644_jpg.rf.d3c73d286a56cf2587469a5845468703.jpg
#
#
# Processing image: 003712_jpg.rf.019a9a6340ea6028c88ff2d924d1f35c.jpg
#
#
# Processing image: 003745_jpg.rf.9bff82722211068cf83e222c5fc406e8.jpg
#
#
# Processing image: 003753_jpg.rf.e4b7518e231c5486203e57e8b9ec5ccc.jpg
#
#
# Processing image: 0037a2e5d0aacc4a_jpg.rf.d7156967debbd2ced6caa226711b3ca3.jpg
#
#
# Processing image: 0037ff44ed11c568_jpg.rf.5ab4c35cae2878f41772db5e0ae44053.jpg
#
#
# Processing image: 003900_jpg.rf.bda12573c5ccf24e2972f5eec8a17c28.jpg
#
#
# Processing image: 00394_jpg.rf.29b7debc3dee2d1fa229184ceccd5f14.jpg
#
#
# Processing image: 003959_jpg.rf.e4d1afb3b46e755c28f3bfb8c456560f.jpg
#
#
# Processing image: 003964_jpg.rf.4fc83835af23819f4a828965680a8fc3.jpg
#
#
# Processing image: 00399_jpg.rf.f14c93eae4c53eff656df63d9237e491.jpg
#
#
# Processing image: 0039df5da0090751_jpg.rf.50a54e7c51cef66c5cc60cf67d3b9d8f.jpg
#
#
# Processing image: 004022_jpg.rf.12d2d1316468f9c964e47e4bc505f76c.jpg
#
#
# Processing image: 004066_jpg.rf.4b1270ea22130ec7dda1a59d49261af5.jpg
#
#
# Processing image: 004126_jpg.rf.807e137a0118b69def1cafeecbeb40f9.jpg
#
#
# Processing image: 004164_jpg.rf.f234d1b30736525620c59b8c2b47d73b.jpg
#
#
# Processing image: 004166_jpg.rf.f8bff2f0d6e2dc3f5536f006b562c105.jpg
#
#
# Processing image: 00421_jpg.rf.495a3cc7249977cae1c8f1e908156c8f.jpg
#
#
# Processing image: 004220_jpg.rf.2e2844f5a39e816f43c9ec8e120f7f28.jpg
#
#
# Processing image: 00425_jpg.rf.39414ae7c1d75502a0cc56647725544b.jpg
#
#
# Processing image: 004327_jpg.rf.df55e8192a9cf8fbce2ae679a844b74d.jpg
#
#
# Processing image: 004341_jpg.rf.84154b4e1c8b76cc1b1449677ae47147.jpg
#
#
# Processing image: 004346_jpg.rf.c715307952445313e418abaeb011179c.jpg
#
#
# Processing image: 00437_jpg.rf.5792af90d6ba608b8dca939c8bf57c79.jpg
#
#
# Processing image: 004386_jpg.rf.c5139b73474160b5861ef495762910ef.jpg
#
#
# Processing image: 00439_jpg.rf.2cf8c35facc5880946e0709080ade257.jpg
#
#
# Processing image: 004432_jpg.rf.137d505dc4d0dbe546f9e82c10fe83c1.jpg
#
#
# Processing image: 004462_jpg.rf.97c92bca76887f87140c72b083d9d62f.jpg
#
#
# Processing image: 004595_jpg.rf.ef5afa68f4fa88b6710262b9a82fd611.jpg
#
#
# Processing image: 0045_jpg.rf.53c02e37a4b3164df5036d58c9752a6d.jpg
#
#
# Processing image: 004662_jpg.rf.a0dfc460774c24e2b161637bdecbf45f.jpg
#
#
# Processing image: 004679_jpg.rf.7e5d99844fca449e5a194e42ae20383c.jpg
#
#
# Processing image: 004693_jpg.rf.9037dae50d8548551a06c97dadd55d00.jpg
#
#
# Processing image: 00472a18d6288e4b_jpg.rf.5ce04c4361f2965d57c45011e6f4c39d.jpg
#
#
# Processing image: 004773_jpg.rf.167046e72e05589565ea69ab60723def.jpg
#
#
# Processing image: 004775_jpg.rf.452c0904040fa909401d314824e57607.jpg
#
#
# Processing image: 004797_jpg.rf.e9615be937bfdb1db46b6622080d720a.jpg
#
#
# Processing image: 004803_jpg.rf.e90d35a81d1592926f2a10f3adf443ec.jpg
#
#
# Processing image: 004931_jpg.rf.946dc9f64f338d7d3945c9fe1df4f57a.jpg
#
#
# Processing image: 005012_png_jpg.rf.2d382c9e1bf606fafa0c819e281a7b59.jpg
#
#
# Processing image: 005041_jpg.rf.1752738830f294c7e76f23c5ba3c3b71.jpg
#
#
# Processing image: 005074_jpg.rf.c7ab67db384030fb29825c7f99e20ef4.jpg
#
#
# Processing image: 005152_jpg.rf.99137e3657f28dec69998f9ad9d9bea6.jpg
#
#
# Processing image: 005177_jpg.rf.67e4c8e74f729389477c0a74ee0fb8ff.jpg
#
#
# Processing image: 005185_jpg.rf.90087b82e3ec4ed57fd0eae224457c71.jpg
#
#
# Processing image: 005220_jpg.rf.8b014e6b35fa6e14be90c024f092177c.jpg
#
#
# Processing image: 005294_jpg.rf.ed7f81776d9ff4f6b367a870945c2873.jpg
#
#
# Processing image: 0053-2-_jpg.rf.7cd1af354970af5b78ef36dc88b644d8.jpg
#
#
# Processing image: 005324_jpg.rf.69e395c2a206815b02a48daf4c787cd6.jpg
#
#
# Processing image: 005435_jpg.rf.02852b5b39bdcdcca8756bd5fbb291bd.jpg
#
#
# Processing image: 005448_jpg.rf.df307c6b34167f500903cf5a46734416.jpg
#
#
# Processing image: 005557_jpg.rf.b8d6b7ee21f6106cf1456aa3043c58fb.jpg
#
#
# Processing image: 0055c50b55aa1793_jpg.rf.025d8b147dd62dbc160b4f718a85adc3.jpg
#
#
# Processing image: 005644_jpg.rf.e3f2e82edee6844324d9d7a11d29e3d9.jpg
#
#
# Processing image: 005676_jpg.rf.17ac898482bbc8cc80acd58a0f1ed150.jpg
#
#
# Processing image: 005787_jpg.rf.33d27572fef868ce745f481365418321.jpg
#
#
# Processing image: 0058-4-_jpg.rf.a38ccbc1f0f20c32b69e508c76933ab6.jpg
#
#
# Processing image: 005801_jpg.rf.bc96566a9249ed53a4d68cee19216481.jpg
#
#
# Processing image: 00581_jpg.rf.f22b0c04de166d3dac7f83987bd2b9df.jpg
#
#
# Processing image: 005840_jpg.rf.f0ef354411299a9f022c674e07b6dcd5.jpg
#
#
# Processing image: 0058dac52c595ecb_jpg.rf.092182ed64b09fca6c9caf7d45abfed1.jpg
#
#
# Processing image: 005904_jpg.rf.6040df027a8010b75bb402d635eb9966.jpg
#
#
# Processing image: 005985_jpg.rf.2ec05602ae148c210531e7ff22e0fece.jpg
#
#
# Processing image: 005987_jpg.rf.e7e6c202b8a51b723075b1584094fbbb.jpg
#
#
# Processing image: 0059a8de9a1a7c52_jpg.rf.28b5d145903c25baad35a49e1eab161a.jpg
#
#
# Processing image: 0059df9ab60c150c_jpg.rf.427cff60df3f47eeda1c8d8ce4ae72aa.jpg
#
#
# Processing image: 0060-3-_jpg.rf.0e5e7f086a153a98022e4001e3c519c1.jpg
#
#
# Processing image: 006060_jpg.rf.a071de3b5068b6485a423070d60c8fcf.jpg
#
#
# Processing image: 006104_jpg.rf.b8d9e12ba40ca04c911f058504613357.jpg
#
#
# Processing image: 00614_jpg.rf.3fcdb3f8e2fc6f7f3ce123ae72ad112f.jpg
#
#
# Processing image: 00616_jpg.rf.e14e48e0d5ed7310c2cf90dc9fac7030.jpg
#
#
# Processing image: 006285_jpg.rf.4e295f0da1eea02543950ae2886e710f.jpg
#
#
# Processing image: 006295_jpg.rf.70e184d6b6c6b6a99cb81d5e7146d83c.jpg
#
#
# Processing image: 006392_jpg.rf.3a33de65ed46c2942b6773a89a479e24.jpg
#
#
# Processing image: 0063f473e6a877a8_jpg.rf.e7d0e1f7b1955b10f57dd961e141c136.jpg
#
#
# Processing image: 006431_jpg.rf.53e137521ba8dc06b2fb3b3b596d4b17.jpg
#
#
# Processing image: 006518_jpg.rf.c9d2d841c4a7a619bdbccfd13dbe10fe.jpg
#
#
# Processing image: 006564_jpg.rf.01dcb09c6029b481c383695f09f540cd.jpg
#
#
# Processing image: 006571_jpg.rf.c9ad5d94c3e19cabe0367667f0d8571e.jpg
#
#
# Processing image: 006575_jpg.rf.56e9b1f854c92a78cb03d8e8fe6705e9.jpg
#
#
# Processing image: 006580_jpg.rf.73c0466485ac2c941802211f744365d8.jpg
#
#
# Processing image: 006641_jpg.rf.9c5f7d19cab716f9a7fb0ec2db9eb775.jpg
#
#
# Processing image: 0066590ad77f7871_jpg.rf.b0371489a89b7ce7da0aa6aa1fe00162.jpg
#
#
# Processing image: 006669_jpg.rf.c2d8086fe0b752cc7eb533807baf5665.jpg
#
#
# Processing image: 00667dcce3163607_jpg.rf.0c9a21e12623c4d0d991bd474663fef0.jpg
#
#
# Processing image: 006703_jpg.rf.643da9d47b073b967f898d3fb921cec4.jpg
#
#
# Processing image: 00675_jpg.rf.302154454786070b52d0c9fe9b79479f.jpg
#
#
# Processing image: 0067b792e99eb379_jpg.rf.0a3c2b9be45bc02dc3dc2778215ab884.jpg
#
#
# Processing image: 006852_jpg.rf.7d637bb8e98f806e283c9fab44564e2f.jpg
#
#
# Processing image: 006901_jpg.rf.d08063696cb66ac6d4192ad62df80760.jpg
#
#
# Processing image: 00701_jpg.rf.240181715e0d48d5a51c6e1e8b058a09.jpg
#
#
# Processing image: 007068_png_jpg.rf.c8d23331294fbc418fafdceabcb9c541.jpg
#
#
# Processing image: 007085_png_jpg.rf.116a9cdf398dcb25a335775fde2ab90e.jpg
#
#
# Processing image: 007086_png_jpg.rf.de2e02542ab1888e301a4bfdf60bfab3.jpg
#
#
# Processing image: 007089_jpg.rf.c945ee0bbd11f99187b42616ecda03ef.jpg
#
#
# Processing image: 007095_png_jpg.rf.2d3f97250330ca0c2d70fdd733852471.jpg
#
#
# Processing image: 007102ce91b2b873_jpg.rf.f578c2b91624e5a58a613675c7a223bb.jpg
#
#
# Processing image: 007118_jpg.rf.08eb2afd28293afc0f53474348b3ccab.jpg
#
#
# Processing image: 007137_jpg.rf.29f0bec6cbed14ffb10e88a6213f2a6a.jpg
#
#
# Processing image: 007139_jpg.rf.10e012b45be1aac87e4132b68617a8a9.jpg
#
#
# Processing image: 007158_jpg.rf.05b67816f533f4b0f388dce2fcb051f4.jpg
#
#
# Processing image: 007200_jpg.rf.6b1de0a9630a24c05e161ad5fbf1cec8.jpg
#
#
# Processing image: 007235_jpg.rf.d7e3256a14a8b23ea4648068870e9da0.jpg
#
#
# Processing image: 007253_jpg.rf.4c7e3619184dd1d317b0f50a4a7b1134.jpg
#
#
# Processing image: 0073-3-_jpg.rf.3a283cf89bb2321e3e3d494b0e9c762b.jpg
#
#
# Processing image: 007310_jpg.rf.99b0010bdeb01c79e3336bf9677b209a.jpg
#
#
# Processing image: 007343_jpg.rf.e7d6759add37fa0bade939b486b58c65.jpg
#
#
# Processing image: 00738acae141b053_jpg.rf.23df10cb0e3323df7538840399267f5d.jpg
#
#
# Processing image: 00739_jpg.rf.b1332922b406dcabe89e35b8a5d15221.jpg
#
#
# Processing image: 0073a06752edc9b1_jpg.rf.5fcc50ebc76f01d3d8f69d5fee96d66a.jpg
#
#
# Processing image: 00741_jpg.rf.60cbdbd3869ec79c6060d383f3818bb7.jpg
#
#
# Processing image: 00744_jpg.rf.28d973fb530f086c170a902ca8c2413d.jpg
#
#
# Processing image: 007452_jpg.rf.2c1acee83aa20338d2d2abd76f5c21f7.jpg
#
#
# Processing image: 007519_jpg.rf.7b03cd09d5ca223567041a596f74bf30.jpg
#
#
# Processing image: 00751_jpg.rf.476176998147449c9fe67f9f812d3ab9.jpg
#
#
# Processing image: 0075bcaef3de1f81_jpg.rf.507d07980056de8e81f0ed0b68bc0ed2.jpg
#
#
# Processing image: 007661_jpg.rf.2dfffe98626b3de0c0ace9f172153c0c.jpg
#
#
# Processing image: 007701_jpg.rf.847c2b95c0f56f75c634212112a47047.jpg
#
#
# Processing image: 007824_jpg.rf.2546c6d0b78429f7a717969fae76cb48.jpg
#
#
# Processing image: 007861_jpg.rf.bccf0c61639130624b4f3769fbd558cd.jpg
#
#
# Processing image: 00786_jpg.rf.5efaee312d41f6127c572b6941d2022b.jpg
#
#
# Processing image: 007958_jpg.rf.9e9897f06ce45a8921bba76e5f68f6b3.jpg
#
#
# Processing image: 0079b702295a2af5_jpg.rf.ac3bbd1f55e69b4049d14a60fce1ff6c.jpg
#
#
# Processing image: 008028_jpg.rf.7364a130db8f34ce4e0d1319693be9c2.jpg
#
#
# Processing image: 008060_jpg.rf.51ad3e0d05af450580231fffc4747d27.jpg
#
#
# Processing image: 008115_jpg.rf.ebfea0b5d39555c1bf96aab84f01bab8.jpg
#
#
# Processing image: 008137_jpg.rf.a8248bd3a4e8defbebba78bb2aa5d246.jpg
#
#
# Processing image: 00817ced730dc364_jpg.rf.27c71cc8dbda5b48da39132920231c5a.jpg
#
#
# Processing image: 008180_jpg.rf.106d3470ae67908297c48a4819e3a836.jpg
#
#
# Processing image: 008188_jpg.rf.75a029b39775e4c8633642234c51a775.jpg
#
#
# Processing image: 008191_jpg.rf.f09c9c5e84e427bf6baf088c422fc24e.jpg
#
#
# Processing image: 00821_jpg.rf.81593969c8308a7837520154b5a804d5.jpg
#
#
# Processing image: 008248_jpg.rf.dab801d6f198e237d61a7176932ef34f.jpg
#
#
# Processing image: 008251_jpg.rf.43a03548c0b08d9cfe179749cdb94e77.jpg
#
#
# Processing image: 008313_jpg.rf.da1d232953584d1d364443efb85911bc.jpg
#
#
# Processing image: 00831_jpg.rf.46c11164522d62b23ed686907cc666a1.jpg
#
#
# Processing image: 00834_jpg.rf.6a46784d6af00e36e52fa60e8d4a0610.jpg
#
#
# Processing image: 008398_jpg.rf.4c6c10bf7b0730b6c5762dad4e937883.jpg
#
#
# Processing image: 008412_jpg.rf.a4f6ae4cedd34ccc9af24120ae36c864.jpg
#
#
# Processing image: 008462_jpg.rf.91431c4d8ebd8994bb0aaf8166fd6491.jpg
#
#
# Processing image: 008468_jpg.rf.a38d375037406b3fc3353bf33d2a9700.jpg
#
#
# Processing image: 008503_jpg.rf.4992d0768cb43679cafdac656804ca63.jpg
#
#
# Processing image: 008553_jpg.rf.c858b6341de70160830977c39223780f.jpg
#
#
# Processing image: 008590_jpg.rf.b8683a4926fc0e9d0f298f8b85890dae.jpg
#
#
# Processing image: 008682_jpg.rf.2a55628f06e47a99cec4ce6179222105.jpg
#
#
# Processing image: 008786_jpg.rf.29e21f721179f08cfa206a4789af23ec.jpg
#
#
# Processing image: 008794_jpg.rf.fb94a31dc5b8657d3f776c41c903ae3d.jpg
#
#
# Processing image: 008819_jpg.rf.a0e621fc18c03575094550c3d7fe7d9f.jpg
#
#
# ...
#
#
# Processing image: xemay82_jpg.rf.1c3b8517bd1b34fe34695de4f5a0f58e.jpg
#
#
# Processing image: xemay848_jpg.rf.d8ec8db822da4ce031cf9b958bf5ebc1.jpg
#
#
# Processing image: xemay857_jpg.rf.84ea5c131d45e6ead99212c9bf67d067.jpg
#
#
# Processing image: xemay860_jpg.rf.9c887c6423a64fbb382432a483b4f78a.jpg
#
#
# Processing image: xemay898_jpg.rf.090cdace25624b115fa2d11a089d93f5.jpg
#
#
# Processing image: xemay906_jpg.rf.3b6b40ece7dceccf9ccb7ababb059ab6.jpg
#
#
# Processing image: xemay928_jpg.rf.a838a4bb46530d1a4daa07e4025f04c5.jpg
#
#
# Processing image: xemay941_jpg.rf.2bd25bd0d4ead8958f5ddd3498b9481b.jpg
#
#
# Processing image: xemay962_jpg.rf.8c4c93aa3b920af2ece118daada0163e.jpg
#
#
# Processing image: xemay969_jpg.rf.763f775b7b787da529f40cc6fb1d359e.jpg
#
#
# Processing image: xemay984_jpg.rf.a8dcf5e34ea6c6ed43a7391f600a6e01.jpg
#
#
# Processing image: xemayBigPlate180_jpg.rf.b2eac7ce605cc255c41c804cb6544532.jpg
#
#
# Processing image: xemayBigPlate30_jpg.rf.832efeeea79aafde3541cfe3d9ed8d50.jpg
#
#
# Processing image: xemayBigPlate9_jpg.rf.28a5c0a372925b3601745ea183191fc1.jpg
#
#
# Processing image: XJ884TROR3EL_jpg.rf.d757bdca415b8a48cdb6554a1a4f3990.jpg
#
#
# Processing image: XM3GCTO4S28F_jpg.rf.fadb08c1e44c14b2703efc140c1af8cd.jpg
#
#
# Processing image: XRJKJL7DKP5C_jpg.rf.275ceae1f072fc52fdea8ac240815bc4.jpg
#
#
# Processing image: xuxckI_k_O64KoNXttVnEiAJpdRx06rDfaX8gSLB9p46f3_d9cn0AKhX4X-AA1gay2n1wyhIMXgeSZWfnX6xJm7l_jpg.rf.a6a764e9fd69c8f9a9948d4cb17f67dc.jpg
#
#
# Processing image: XVMZ924NFFU3_jpg.rf.cb3a5534479e7029db28d5e14ad6e703.jpg
#
#
# Processing image: XX85WI3I925V_jpg.rf.4a08c8acb252d0b032996b33c9043d60.jpg
#
#
# Processing image: y-101-_jpg.rf.0bb8862e09ca322d4e7084bcdf9ebc8a.jpg
#
#
# Processing image: y-114-_jpg.rf.251a0bd79c0da0eb7b414907998ae31a.jpg
#
#
# Processing image: y-116-_jpg.rf.e3a791546cd127080baf1c039bbc1b46.jpg
#
#
# Processing image: y-122-_jpg.rf.3e4baade2fae0608c88037d0d72526bf.jpg
#
#
# Processing image: y-16-_jpg.rf.537bec33a27d2022074e771e7132b88f.jpg
#
#
# Processing image: y-27-_jpg.rf.a8661fcca2d9f1a84fb52f24b51a10b1.jpg
#
#
# Processing image: y-28-_jpg.rf.4c520eaa35537aecba2710db466e0580.jpg
#
#
# Processing image: y-4-_jpg.rf.8d888f36704b658dc6f3caea11e9d375.jpg
#
#
# Processing image: y-40-_jpg.rf.1b4b4113ff26912c2b012d5d707b0df1.jpg
#
#
# Processing image: y-44-_jpg.rf.1cc0c921853739ab38f0eea98a880778.jpg
#
#
# Processing image: y-48-_jpg.rf.67e482502e067b81ea833825a7a314fa.jpg
#
#
# Processing image: y-57-_jpg.rf.378096178285cf93c17e4ca5634c2542.jpg
#
#
# Processing image: y-69-_jpg.rf.70dd350da224ad3ee65d647cdeed5e5f.jpg
#
#
# Processing image: y-83-_jpg.rf.c04bc1f05c8791eff885994855216943.jpg
#
#
# Processing image: y-89-_jpg.rf.297ea354f67698f868346405c2758dfc.jpg
#
#
# Processing image: y-97-_jpg.rf.4128849a650f66cf1a5c214a0e11dd43.jpg
#
#
# Processing image: Y2E82SPWZ95U_jpg.rf.bb3cbd3ea8ab8cdf2cce4bf5f60fff48.jpg
#
#
# Processing image: Y2XP2SL5FXFD_jpg.rf.68ae0d37a364d8f8638e35619988f18e.jpg
#
#
# Processing image: Y32JRLFRW6UD_jpg.rf.3ad4728276dd566951f3717b2a8510ee.jpg
#
#
# Processing image: Y4Y4IQOWJ9NM_jpg.rf.cdc815ffb2b12fd1715812cde12340bc.jpg
#
#
# Processing image: Y7O19EK0LNHI_jpg.rf.190d942fb63696a673d78420421de290.jpg
#
#
# Processing image: YCOBKMIGYG51_jpg.rf.b1d2ed8a30da423ba0affba22d3e9f2e.jpg
#
#
# Processing image: YEA2G9OZQ3FB_jpg.rf.d639bd78986ea4c432b7bc6bdf668f35.jpg
#
#
# Processing image: YHV5X50CH297_jpg.rf.515d2cfef82dca57166bf5c788b8c517.jpg
#
#
# Processing image: YJUYAV5ASN3W_jpg.rf.fba279c376b55c52db4a672e1a1ee88f.jpg
#
#
# Processing image: YM2M0XG1P7G7_jpg.rf.cdccb80f062e6ed5d1b26c8e3062acf9.jpg
#
#
# Processing image: young-woman-in-yellow-hardhat-orange-reflective-vest-lumberjack-shirt-KK36W4_jpg.rf.948eec12e2daa7b991f7f4a5f7336897.jpg
#
#
# Processing image: youtube-105_jpg.rf.1703c35a1bdb0628462b240f6166b6a8.jpg
#
#
# Processing image: youtube-109_jpg.rf.986d3039af203dbf8a08dd6c8f9680a7.jpg
#
#
# Processing image: youtube-110_jpg.rf.b9613241038e36e0891bcf4aa5423267.jpg
#
#
# Processing image: youtube-114_jpg.rf.bb711a90a19e752a9cd98635bde64915.jpg
#
#
# Processing image: youtube-117_jpg.rf.71330bc3a23244b2bc9dafc552fe9e3e.jpg
#
#
# Processing image: youtube-11_jpg.rf.b8ac97fb29e4c06f72bb3635bc2aaac7.jpg
#
#
# Processing image: youtube-11_jpg.rf.d3418d2a45594eb265a30732cc05598f.jpg
#
#
# Processing image: youtube-120_jpg.rf.09bd953083a44f0309b72aa2c04d8c0e.jpg
#
#
# Processing image: youtube-121_jpg.rf.55f0d3d756c017ab16d62dd92aa4f4ff.jpg
#
#
# Processing image: youtube-122_jpg.rf.3481020bbac0800234c5c7b0d12ac0b5.jpg
#
#
# Processing image: youtube-126_jpg.rf.b014f1c96b85ee33c8727a46a78eb7d1.jpg
#
#
# Processing image: youtube-126_jpg.rf.e9b92eeacd042f5f5f969b7a758fc919.jpg
#
#
# Processing image: youtube-129_jpg.rf.253751ef0c253ad4d39428a8b2b43cbb.jpg
#
#
# Processing image: youtube-134_jpg.rf.09eda7e35b4d2c52a27e618dcb5e537c.jpg
#
#
# Processing image: youtube-137_jpg.rf.82480baf0672582a887ad931ad8d040b.jpg
#
#
# Processing image: youtube-137_jpg.rf.cc16ced16157edb1a9d4666b1242c483.jpg
#
#
# Processing image: youtube-143_jpg.rf.23a959e36b4849c9b76c954edc1c2554.jpg
#
#
# Processing image: youtube-146_jpg.rf.4178ae01669910d50f3828b703fd5160.jpg
#
#
# Processing image: youtube-146_jpg.rf.d6ee42e18940a4d48fecd387ad784b5b.jpg
#
#
# Processing image: youtube-152_jpg.rf.2e7ca0d285844b18600223fb9725de8e.jpg
#
#
# Processing image: youtube-154_jpg.rf.59c0bcad24dc63c0d143b156f4083b83.jpg
#
#
# Processing image: youtube-158_jpg.rf.279ef03a841feda2c32c595409913f5e.jpg
#
#
# Processing image: youtube-158_jpg.rf.6409d8a8d84d7a04854423fa383ad3d1.jpg
#
#
# Processing image: youtube-15_jpg.rf.50b1c17d95b733372b88bb0b345b57ed.jpg
#
#
# Processing image: youtube-161_jpg.rf.929bf17750814847017d0198a351e929.jpg
#
#
# Processing image: youtube-163_jpg.rf.eab454e08051b5e5fab8632e244a51ad.jpg
#
#
# Processing image: youtube-167_jpg.rf.baa1309c08b2558381deaa774fdd763e.jpg
#
#
# Processing image: youtube-167_jpg.rf.cb4b86ccc69992c900be78e126fa4f8b.jpg
#
#
# Processing image: youtube-170_jpg.rf.14e0da457cc44531790425d6c89283f8.jpg
#
#
# Processing image: youtube-17_jpg.rf.2f806ce89d88b5a7d17531145030551f.jpg
#
#
# Processing image: youtube-181_jpg.rf.2eaa0a93305306f75900672cea3c484d.jpg
#
#
# Processing image: youtube-181_jpg.rf.7e68278fe164409bec5b8430dfeeaebb.jpg
#
#
# Processing image: youtube-184_jpg.rf.3fb9ebb8a5b420d779f40171d2e78fac.jpg
#
#
# Processing image: youtube-187_jpg.rf.99b89b7235d01012be475ee3361eeb12.jpg
#
#
# Processing image: youtube-189_jpg.rf.edc32f47c5a046fa07fa54037d1e17ea.jpg
#
#
# Processing image: youtube-18_jpg.rf.d5acd88c23a1cab22713c7d1036a3ced.jpg
#
#
# Processing image: youtube-191_jpg.rf.aa264c8261376e0dce24547a54c41fc5.jpg
#
#
# Processing image: youtube-191_jpg.rf.d7e46033acab89c20c27ad37332f345e.jpg
#
#
# Processing image: youtube-195_jpg.rf.811c40fb0ba5fe5493f765094c7f0dab.jpg
#
#
# Processing image: youtube-198_jpg.rf.57cc5773e210713a24c4f865ad602d65.jpg
#
#
# Processing image: youtube-19_jpg.rf.f00616fa6cf6fd665c925788315417a5.jpg
#
#
# Processing image: youtube-204_jpg.rf.50025919c5770f1979db0ed91efdf5ec.jpg
#
#
# Processing image: youtube-208_jpg.rf.398e461008df8a51248876421f009c19.jpg
#
#
# Processing image: youtube-211_jpg.rf.f79ef868385494f5e0ef056d59557b78.jpg
#
#
# Processing image: youtube-216_jpg.rf.ca5ff30645eb8456c75f5359b0a243b2.jpg
#
#
# Processing image: youtube-217_jpg.rf.1cddcf2ea34b9d85d863bc439ef5f693.jpg
#
#
# Processing image: youtube-217_jpg.rf.842508564dbb18b517c8ad091944d4e1.jpg
#
#
# Processing image: youtube-218_jpg.rf.a8bd1b414e91e8c44cc1063b6faf0712.jpg
#
#
# Processing image: youtube-219_jpg.rf.9d67817ff10fcf556880958f83cbb69a.jpg
#
#
# Processing image: youtube-220_jpg.rf.015fc42bf5ba160a3d5910a8d291dfb2.jpg
#
#
# Processing image: youtube-224_jpg.rf.9c1db1a727ffd6c13bd59ee8ecb45d4c.jpg
#
#
# Processing image: youtube-231_jpg.rf.49208a94b84b83c03f1562a107801c83.jpg
#
#
# Processing image: youtube-233_jpg.rf.aa49e6037775c54432e2444e90beec62.jpg
#
#
# Processing image: youtube-234_jpg.rf.a2229b7466daacd16489f60214c94890.jpg
#
#
# Processing image: youtube-23_jpg.rf.d4ccc6149eac31fbbe5e502b9714a24a.jpg
#
#
# Processing image: youtube-240_jpg.rf.e98f25bbbb3a06343e9fac0167cb1207.jpg
#
#
# Processing image: youtube-245_jpg.rf.b7727e1594ef1160a8b7e9106ab2d91d.jpg
#
#
# Processing image: youtube-25_jpg.rf.72dc5fa20b94709cef3eb9dd38b04fb9.jpg
#
#
# Processing image: youtube-269_jpg.rf.2425a9658eb91eaa2138428481065b53.jpg
#
#
# Processing image: youtube-26_jpg.rf.ddd8f68952c5237f7eb14fec4dda469b.jpg
#
#
# Processing image: youtube-27_jpg.rf.e021e1365a58cca8b633feb576510626.jpg
#
#
# Processing image: youtube-27_jpg.rf.f240c26aec964bce2142172ef72fada6.jpg
#
#
# Processing image: youtube-284_jpg.rf.fc24ff2bfe7dd5910b8374a70342fbf2.jpg
#
#
# Processing image: youtube-292_jpg.rf.703fcc1e699a8120e2eb677d6ac7e3ea.jpg
#
#
# Processing image: youtube-29_jpg.rf.c386575c3a8042e03c4825309cd18cb6.jpg
#
#
# Processing image: youtube-2_jpg.rf.49ce6a83c2711bd7090c43a56b83d806.jpg
#
#
# Processing image: youtube-2_jpg.rf.bf7290b006eeb60294353cda279d3fc8.jpg
#
#
# Processing image: youtube-310_jpg.rf.dada3a2b984ea4ef8d88bb217db92940.jpg
#
#
# Processing image: youtube-328_jpg.rf.98f8119660c7387bc4c81a5a9825beba.jpg
#
#
# Processing image: youtube-33_jpg.rf.3341da76d9c8e7452ee153f26ceb7069.jpg
#
#
# Processing image: youtube-34_jpg.rf.53c591b6fa7a8bf8a8ce703dd3ba775a.jpg
#
#
# Processing image: youtube-34_jpg.rf.90a122a8b9a8983e20093111cad2b57d.jpg
#
#
# Processing image: youtube-35_jpg.rf.4e6f8c7069d8e020c4a456bb9694c856.jpg
#
#
# Processing image: youtube-35_jpg.rf.d439e13abcc761d0f9f4f7cbdef346a4.jpg
#
#
# Processing image: youtube-39_jpg.rf.8edf7aaa89e06240b9eab82b5e3f92cc.jpg
#
#
# Processing image: youtube-41_jpg.rf.c9d5650882ca75e38905b67db0c236a9.jpg
#
#
# Processing image: youtube-43_jpg.rf.929311587f2e6c3112ed5c4d28da5d46.jpg
#
#
# Processing image: youtube-43_jpg.rf.f9d3115f4b463eb59611d480ca86ff0c.jpg
#
#
# Processing image: youtube-44_jpg.rf.251899fead9216275c3f67618886e7ca.jpg
#
#
# Processing image: youtube-45_jpg.rf.3f8f42e2d06f29a1d0027d747c65150d.jpg
#
#
# Processing image: youtube-49_jpg.rf.8c8a6b25a3f66ca301b03a6e39939fdd.jpg
#
#
# Processing image: youtube-49_jpg.rf.f5c8e21a1dd1d164b015f2abbdbc69f9.jpg
#
#
# Processing image: youtube-53_jpg.rf.9f64ab4a091591d0acca0a787efe6398.jpg
#
#
# Processing image: youtube-55_jpg.rf.8600b034013eaa32a2cf3ee0f7e5ce00.jpg
#
#
# Processing image: youtube-55_jpg.rf.c94f81f03bcadab3bd31f5a85ce3e44b.jpg
#
#
# Processing image: youtube-56_jpg.rf.3aa1935cfe17ea19861fc291d3d14c53.jpg
#
#
# Processing image: youtube-57_jpg.rf.597991d8fb9b400e4b2879bcb15a9440.jpg
#
#
# Processing image: youtube-63_jpg.rf.6ca858391525e039c9dd197ab8f37e36.jpg
#
#
# Processing image: youtube-65_jpg.rf.4e1bbd29fc68d71f9d78dfcc2d1aaf5f.jpg
#
#
# Processing image: youtube-67_jpg.rf.1f221f33109b81838ced4e5b832ef12b.jpg
#
#
# Processing image: youtube-6_jpg.rf.59a82c9e94aeb8a97d648ce2da189833.jpg
#
#
# Processing image: youtube-71_jpg.rf.dda32fed1eb54bc2ea396f9d6619ddc4.jpg
#
#
# Processing image: youtube-74_jpg.rf.7364f0ff11282ead4cc35ed9eafd70ef.jpg
#
#
# Processing image: youtube-75_jpg.rf.01ca355e2394a866568c7e88f7cb336d.jpg
#
#
# Processing image: youtube-76_jpg.rf.9163d92e0e7a70da703ea7e7f5416ec1.jpg
#
#
# Processing image: youtube-78_jpg.rf.f8e11ecbe7dd7ad352d440f342a09b2b.jpg
#
#
# Processing image: youtube-7_jpg.rf.77f3ff5f98d813b83da4281dba1ed3e4.jpg
#
#
# Processing image: youtube-84_jpg.rf.d16fbc651f9ec3fc5b4484170dc5def3.jpg
#
#
# Processing image: youtube-85_jpg.rf.b03ebb3108f6179fae473c5072b1ca8d.jpg
#
#
# Processing image: youtube-85_jpg.rf.b2c766373df90558e9552821323c64c4.jpg
#
#
# Processing image: youtube-87_jpg.rf.133ff2438c349173221db60319fd9eac.jpg
#
#
# Processing image: youtube-87_jpg.rf.2d5e448aae5252ea0abdc35de52e33bb.jpg
#
#
# Processing image: youtube-89_jpg.rf.8ac18b97bd24537d5e16d5f06c46bbd3.jpg
#
#
# Processing image: youtube-8_jpg.rf.872fdeb7b5ce86f30bfcdddf5f6e4c48.jpg
#
#
# Processing image: youtube-90_jpg.rf.34d4ca143d8b2085595e59c9a0b46f60.jpg
#
#
# Processing image: youtube-90_jpg.rf.578cdecb64a7a899550355b4a5c67e2c.jpg
#
#
# Processing image: youtube-93_jpg.rf.7b5000363661ffd3209e4a66afe7cbb5.jpg
#
#
# Processing image: youtube-94_jpg.rf.eff65a8978458b03f3fd978e034c0253.jpg
#
#
# Processing image: youtube-9_jpg.rf.8192c079ea4d62b8d93fe40c394c6e0e.jpg
#
#
# Processing image: YR5P35S2CKJ7_jpg.rf.46ba01c2d0aa017086a0c6baf9e206c3.jpg
#
#
# Processing image: YT00640_1_jpg.rf.315ff11853e3d726114fdc3686691097.jpg
#
#
# Processing image: YT00640_1_jpg.rf.94d2cade7f4bb6720fe3b92c212804ab.jpg
#
#
# Processing image: yt007_jpg.rf.a0a771e3e72358a3a32fd9cdc08b1003.jpg
#
#
# Processing image: yt010_jpg.rf.dfdea0b174292bf170ced98b1f30f66d.jpg
#
#
# Processing image: yt025_jpg.rf.9ddc1381ed8bc7c3fb0f07960bf8e80d.jpg
#
#
# Processing image: yt028_jpg.rf.458aca72a0cc4873330258a52df42232.jpg
#
#
# Processing image: yt029_jpg.rf.f5e4d67ace69d9c29fdf9620ba1f93e8.jpg
#
#
# Processing image: yt032_jpg.rf.1530abf6d73ea8b5ab1c500c117ae389.jpg
#
#
# Processing image: yt042_jpg.rf.59b076b0d117f08621400c06477fb1cc.jpg
#
#
# Processing image: yt051_jpg.rf.95274df446c56a3af11839c7a26d9655.jpg
#
#
# Processing image: yt067_jpg.rf.2c0ccb57595f995c57987c81bcbb352a.jpg
#
#
# Processing image: yt069_jpg.rf.76a56cf81c2ad5def161f84e88bbeb66.jpg
#
#
# Processing image: yt073_jpg.rf.de7a51020641b04c21cf4e2c67638ea1.jpg
#
#
# Processing image: yt085_jpg.rf.62f45f0ba31b1a9f3f792304e483aa17.jpg
#
#
# Processing image: yt123_jpg.rf.7f143a9d074e8a43508ab2f74583c9bb.jpg
#
#
# Processing image: yt126_jpg.rf.7fc0074daf1987a2b963f986c736b9cf.jpg
#
#
# Processing image: yuvraj-singh-UhLQ8t_-etA-unsplash_jpg.rf.9a3f42bc1a10f41482a24ff203e98793.jpg
#
#
# Processing image: YWDJNT1PJYWG_jpg.rf.3702ae333efe7c92983ba24ab7555028.jpg
#
#
# Processing image: YWECF9JQZYHW_jpg.rf.99c712e88edcb5453ec817ba4f1ff4e6.jpg
#
#
# Processing image: YWECF9JQZYHW_jpg.rf.c83f023baecf9b66909b10a7bca0c52b.jpg
#
#
# Processing image: YWP8CMOHBX5D_jpg.rf.17209ca02dca07d37671a3f949e8654c.jpg
#
#
# Processing image: YZFTGL8FLFTU_jpg.rf.cb3ae5a3ee782355cbaf054e7906c3df.jpg
#
#
# Processing image: YZZ08NNYF82X_jpg.rf.de167375536a978fd4bf50d55cf5d5d7.jpg
#
#
# Processing image: Z003TF03UTK1_jpg.rf.7f3736ea46c0106ecf52e72720c884f3.jpg
#
#
# Processing image: Z0EE18H9T356_jpg.rf.51ea13198753e6b409853e7620cd5a0b.jpg
#
#
# Processing image: Z0EE18H9T356_jpg.rf.ca651413adad7762c8c84c7c1c395461.jpg
#
#
# Processing image: Z0JFRRSXCZ6J_jpg.rf.13fc73f2f1bc082f5265347c5360ffef.jpg
#
#
# Processing image: Z12C7uff_JPG_jpg.rf.09a29795ab9ba107dbd9b152b56237d6.jpg
#
#
# Processing image: Z1YNPNIWVQTU_jpg.rf.a2f4f881f423374c40373e542233267c.jpg
#
#
# Processing image: Z2FAFX4CS2XI_jpg.rf.139bd0f509c744b03ab755bba9c68f0a.jpg
#
#
# Processing image: Z2FAFX4CS2XI_jpg.rf.ca37cc64eba792d4fae5f2f275b6e488.jpg
#
#
# Processing image: Z4O1QGC67T8D_jpg.rf.d9323ecfff8f699a1ac088dd1e01fcba.jpg
#
#
# Processing image: Z9NKO2EHC3EI_jpg.rf.4f47c865670a55eaba4a9f496c6e6fcc.jpg
#
#
# Processing image: ZAV6CTV3LWKN_jpg.rf.eea6eda03da66601833c7799af5dcda7.jpg
#
#
# Processing image: ZBG866OVRWXO_jpg.rf.9ddf5ce080c20638fa2dc2c5f8bd068d.jpg
#
#
# Processing image: ZCKROF0UR45E_jpg.rf.39edc201e637101458f9e4c419768769.jpg
#
#
# Processing image: ZCKROF0UR45E_jpg.rf.edd0facb8da43477b58e5866e2f3bfe4.jpg
#
#
# Processing image: ZGIOEFI2A67T_jpg.rf.8631391de0858dbfce1f9d9c4ac6c60c.jpg
#
#
# Processing image: ZGIOEFI2A67T_jpg.rf.be3e9a55cd013bceeff8357ec7d6df49.jpg
#
#
# Processing image: ZJRTKVWTPI7V_jpg.rf.aee771200c80f5d0781503db948a61e6.jpg
#
#
# Processing image: ZJYEFRZ440WS_jpg.rf.fdcd8efdd6f98a1f103ff18e2c49e364.jpg
#
#
# Processing image: znak0124-_jpg.rf.c3095d786c080c33acb5efaf7861740c.jpg
#
#
# Processing image: znak0125-_jpg.rf.9227ee8c08849d723d1c62d12e6b5942.jpg
#
#
# Processing image: znak0241-_jpg.rf.e42a126be0dcbafdc79bb9cfb5df5a1d.jpg
#
#
# Processing image: znak0477-_jpg.rf.47f0dfa6d2dfc310888cfeb536f175f1.jpg
#
#
# Processing image: znak0839-_jpg.rf.08924e406ba06a56b0e681d74b306379.jpg
#
#
# Processing image: znak0852-_jpg.rf.93faab8c3eda2e05a36fee58792d5c3c.jpg
#
#
# Processing image: znak0921-_jpg.rf.3665b85e2f0da7178eccdd5c90549c93.jpg
#
#
# Processing image: znak1183-_jpg.rf.0cbd3bda9162f3ea19feef7825280230.jpg
#
#
# Processing image: znak1240-_jpg.rf.2debfd8ccbe4ea53218c69446aedd023.jpg
#
#
# Processing image: ZQKVXKK7T5QX_jpg.rf.f5c8847653089012e33f8f16803d2448.jpg
#
#
# Processing image: ZR4KVSR7BYVN_jpg.rf.bce1885e66bf02aa799bcb7b81aeb6c0.jpg
#
#
# Processing image: ZSHRW12NGU9N_jpg.rf.184c0bdbb8d90315575e5f18043e455b.jpg
#
#
# Processing image: ZSL05DP80OFE_jpg.rf.961e79e435bfa12e0b489f85c91263b2.jpg

# %%
#  Precision and Recall for Model 1
precision_model1 = true_positives_model1 / (true_positives_model1 + false_positives_model1) if (true_positives_model1 + false_positives_model1) > 0 else 0
recall_model1 = true_positives_model1 / (true_positives_model1 + false_negatives_model1) if (true_positives_model1 + false_negatives_model1) > 0 else 0

# Precision and Recall for Model 2
precision_model2 = true_positives_model2 / (true_positives_model2 + false_positives_model2) if (true_positives_model2 + false_positives_model2) > 0 else 0
recall_model2 = true_positives_model2 / (true_positives_model2 + false_negatives_model2) if (true_positives_model2 + false_negatives_model2) > 0 else 0

# Print 
print("Model 1 Performance:")
print(f"True Positives: {true_positives_model1}")
print(f"False Positives: {false_positives_model1}")
print(f"False Negatives: {false_negatives_model1}")
print(f"Precision: {precision_model1:.2f}")
print(f"Recall: {recall_model1:.2f}")

print("\nModel 2 Performance:")
print(f"True Positives: {true_positives_model2}")
print(f"False Positives: {false_positives_model2}")
print(f"False Negatives: {false_negatives_model2}")
print(f"Precision: {precision_model2:.2f}")
print(f"Recall: {recall_model2:.2f}")

# Argument for ideal model..
if precision_model1 > precision_model2 and recall_model1 > recall_model2:
    favored_model = "Model 1"
    reason = "Model 1 has higher precision and recall, indicating better overall performance in detecting objects correctly while minimizing false detections."
elif precision_model2 > precision_model1 and recall_model2 > recall_model1:
    favored_model = "Model 2"
    reason = "Model 2 has higher precision and recall, indicating better overall performance in detecting objects correctly while minimizing false detections."
elif precision_model1 > precision_model2:
    favored_model = "Model 1"
    reason = "Model 1 has higher precision, indicating it produces fewer false positives compared to Model 2."
elif precision_model2 > precision_model1:
    favored_model = "Model 2"
    reason = "Model 2 has higher precision, indicating it produces fewer false positives compared to Model 1."
elif recall_model1 > recall_model2:
    favored_model = "Model 1"
    reason = "Model 1 has higher recall, indicating it detects more true objects compared to Model 2."
else:
    favored_model = "Model 2"
    reason = "Model 2 has higher recall, indicating it detects more true objects compared to Model 1."

print(f"\nBased on the evaluation metrics, the favored model is {favored_model}.")
print(reason)
# Out:
# Model 1 Performance:
# True Positives: 14358
# False Positives: 4380
# False Negatives: 22357
# Precision: 0.77
# Recall: 0.39
#
# Model 2 Performance:
# True Positives: 16343
# False Positives: 4044
# False Negatives: 20372
# Precision: 0.80
# Recall: 0.45
#
# Based on the evaluation metrics, the favored model is Model 2.
# Model 2 has higher precision and recall, indicating better overall performance in detecting objects correctly while minimizing false detections.
